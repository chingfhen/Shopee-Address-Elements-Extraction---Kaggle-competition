# %% [markdown]
# # Results:
# - a combination of text classification and question answering acquired a score of **57% accuracy which is ranked 150 out of 1000 competitors

# %%
from IPython.display import Image
Image(r"C:\Users\tanch\Documents\Coding Competitions\Shopee\Shopee Address Elements Extraction (local)\predictions\FINAL SCORE.PNG")
