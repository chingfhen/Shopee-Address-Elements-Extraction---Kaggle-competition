# %% [markdown]
# # ABOUT:
# - in the training some answer spans "man kerto v" have a different answer label "man kertoarjo v"
# - we want to find these mappings that are one to one so that we can confidently replace them in our final predictions

# %% [markdown]
# ## read_csv

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\tanch\Documents\Coding Competitions\Shopee\Shopee Address Elements Extraction (local)\datasets\train.csv\train.csv")

# %%
# split 'POI/street' column into 2 individual columns
df[['POI', 'street']] = df['POI/street'].str.split('/', expand=True)
df = df.drop(["POI/street"],axis=1)

# %%
# convert POI and street to one columns
# remove all rows without answers
df = pd.concat([df.loc[df.street!='',["raw_address",'street']].rename(columns = {"street":"answer"}),df.loc[df.POI!='',["raw_address",'POI']].rename(columns = {"POI":"answer"})],axis=0)
df.head()
# Out:
#                                          raw_address  \
# 0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 2               setu siung 119 rt 5 1 13880 cipayung
# 4                                      jl. orde baru
# 5                   raya samb gede, 299 toko bb kids
# 6  kem mel raya, no 4 bojong rawalumbu rt 1 36 ra...
#
#                                      answer
# 0  jl kapuk timur delta sili iii lippo cika
# 2                                     siung
# 4                             jl. orde baru
# 5                            raya samb gede
# 6                              kem mel raya

# %% [markdown]
# ## Find one to one POI/street mappings
# - given "man kerto v"
#     - it can have many solutions including itself
#         1. 'man kertoarjo v'
#         2. 'manyar kerto v'
#         3. "man kerto v"
# - we want to find abbreviated POI/street that map to exactly one correct POI/street
#     e.g "ahmad dah iv" is mapped to only "ahmad dahlan iv" in the training set

# %%
import numpy as np
def process(address,answer):
#     if answer in address:                                    
#         return np.nan
    
    address_words = address.replace(",","").split()
    answer_words = answer.split()
    
    for i,word in enumerate(address_words):
        if address_words[i] not in answer_words[0]:
            continue
        break
    
    return " ".join(address_words[i:i+len(answer_words)])

# %%
df['answer_in_address'] = df.apply(lambda row: process(row['raw_address'],row['answer']),axis=1)

# %%
df
# Out:
#                                               raw_address  \
# 0       jl kapuk timur delta sili iii lippo cika 11 a ...
# 2                    setu siung 119 rt 5 1 13880 cipayung
# 4                                           jl. orde baru
# 5                        raya samb gede, 299 toko bb kids
# 6       kem mel raya, no 4 bojong rawalumbu rt 1 36 ra...
# ...                                                   ...
# 299989  lapangan bakti, singki', rantepao, kab torut, ...
# 299990                                ver, durian bajenis
# 299992                                kios asmi panaikang
# 299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999          jaya maspion permata blok beryl b2  no.58
#
#                                           answer  \
# 0       jl kapuk timur delta sili iii lippo cika
# 2                                          siung
# 4                                  jl. orde baru
# 5                                 raya samb gede
# 6                                   kem mel raya
# ...                                          ...
# 299989                            lapangan bakti
# 299990                                    veruna
# 299992                                 kios asmi
# 299998                                taman asri
# 299999                      jaya maspion permata
#
#                                answer_in_address
# 0       jl kapuk timur delta sili iii lippo cika
# 2                                          siung
# 4                                  jl. orde baru
# 5                                 raya samb gede
# 6                                   kem mel raya
# ...                                          ...
# 299989                            lapangan bakti
# 299990                                       ver
# 299992                                 kios asmi
# 299998                                taman asri
# 299999                      jaya maspion permata
#
# [351348 rows x 3 columns]

# %%
from collections import defaultdict
mappings = defaultdict(set)
def send_to_mappings(row):
    mappings[row.answer_in_address].add(row.answer)
df[~df.answer_in_address.isna()].apply(lambda x: send_to_mappings(x),axis=1)
# Out:
# 0         None
# 2         None
# 4         None
# 5         None
# 6         None
#           ...
# 299989    None
# 299990    None
# 299992    None
# 299998    None
# 299999    None
# Length: 351348, dtype: object

# %% [markdown]
# - (above) many words like "jati" can be mapped to multiple other answers including itself
#     - 'jati',
#     - 'jatianom',
#     - 'jatipuro',
#     - 'jatirogo',
#     - 'jatiroto',
#     - 'jatisam'
# - we ignore those

# %%
one_to_one_mappings = dict()
for k,s in mappings.items():
    v = next(iter(s))
    if len(s)==1 and k!=v:
        one_to_one_mappings[k] = v

# %%
(one_to_one_mappings)
# Out:
# {'tam asri gg. 7': 'tam asri, gg. 7',
#  'pluit pluit karang jel': 'pluit karang jel 13',
#  'ahmad dah iv': 'ahmad dahlan iv',
#  'cipinang besar selatan': 'cipinang jaya 1a',
#  'gesya gesya': 'gesya resid',
#  'sungai beringin': 'sungai beri',
#  'mamp 2nd': 'mamp prap',
#  'pulori': 'puloriburit',
#  'kar utara': 'karang utara',
#  'gun anyar lor gg. i': 'gun anyar lor, gg. i',
#  'r. wol mongin': 'r. wol monginsidi',
#  'raya banjarn - pur': 'raya banjarnegara - purwok',
#  'colu ten ii': 'columbus ten ii',
#  'bule timur kel gading': 'bulevar timur kel gading',
#  'al maqbul (jalan': 'jalan raya kuwolu',
#  'kel dua raya gg. mel': 'kel dua raya, gg. mel',
#  'jl. mh. thamrin.': 'jl. mh. thamrin',
#  'jatij 2 gg. al chas iv': 'jatij 2, gg. al chas iv',
#  'prabumu': 'prabumulih-b',
#  'pad ii gg. 5': 'pad ii, gg. 5',
#  'jl. gay timur mgp': 'jl. gayung timur mgp',
#  'p. suryaa': 'p. suryaatmaja',
#  'pad ii gg. 1': 'pad ii, gg. 1',
#  'pala 2': 'palasari 2',
#  'taman crys 1': 'taman crystal 1',
#  'jl pluit karang ayu baratpenjaringanjkt': 'jl pluit karang ayu barat',
#  'kra kecil': 'kramat kecil',
#  'indra indra jaya gang': 'indra jaya gang ten',
#  'muti lest 24': 'muti lestari 24',
#  'gran baru vi gg. vi': 'gran baru vi, gg. vi',
#  'tukad band xii': 'tukad bandung xii',
#  'mage & kutu tegal': 'magelang & kutu tegal',
#  'perum sapphire resid': 'perumahan sapphire resid',
#  'pad ii gang 17': 'padema ii gang 17',
#  'gud pel barat': 'gud peluru barat',
#  'simp pag': 'simpang pag',
#  'pon aren ii gg. sate': 'pon aren ii, gg. sate',
#  'kre bun 4': 'krekot bun 4',
#  'tang mas timur ii': 'tanggul mas timur ii',
#  'jatine kaum': 'jatinegara kaum',
#  'perintis kemerd iii': 'perintis kemerdekaan iii',
#  'jl. per neg i': 'jl. percet neg i',
#  'kamp kepu gg. vii': 'kamp kepu, gg. vii',
#  'ploso kel. ploso': 'ploso timur iv',
#  'y soed ii b': 'y soedarso ii b',
#  'raya rut': 'raya ruteng',
#  'jangli tla v': 'jangli tlawah v',
#  'p. kem iii': 'p. kemerd iii',
#  'sut flamb 6': 'sut flamboyan 6',
#  'pur iv': 'purnab iv',
#  'gad raya g 14': 'gad raya, g 14',
#  'citra yuda iv peru depok': 'citra yuda iv  peru depok',
#  'bina asih ii gg. h. kunin': 'bina asih ii, gg. h. kunin',
#  'j peg ind bar ii e': 'j pegang ind bar ii e',
#  'prof muha yamin i': 'prof muhammad yamin i',
#  'sira siraman': 'siraman pulu',
#  'taman kahya': 'taman kahyangan',
#  'pulo padang pulo pad': 'pulo pad - mar',
#  'taman keba indah blok p': 'taman kebalen indah blok p',
#  'jl. jl. jend sudi': 'jl., jl. jend sudi',
#  'sut siswomi': 'sut siswomiharjo',
#  'bano ten i': 'banowati ten i',
#  'kamp hutan tua': 'kampung hutan tua',
#  'l no 17': 'jl. syarifuddin yoes',
#  'raya padang panj - buk': 'raya padang panj - bukitt',
#  'sel permai': 'selong permai',
#  'perd oti 2': 'perdatam oti 2',
#  't1 gg. tela': 't1, gg. teladan',
#  'jl. giri mekar per 3 b': 'jl. giri mekar permai 3 b',
#  'kenc utara ii': 'kencana utara ii',
#  'lap.pors gg. iii': 'lap.pors, gg. iii',
#  'tanj duren dalam 6': 'tanjung duren dalam 6',
#  'kalbar': 'jln.ngura',
#  'perum taman setia': 'perumahan taman setiabudi',
#  'pon muti raya ii': 'pondok muti raya ii',
#  'punia)': 'jl. sriwijaya',
#  'rawa simp 8': 'rawa simprug 8',
#  'raya mangu-bo': 'raya mangu-boyolali',
#  'putat jaya gg. lebar a': 'putat jaya, gg. lebar a',
#  'gang pen': 'gang pendid',
#  'lin sumatera kemu': 'lintas sumatera kemu',
#  'jalan sabang merahkelurahan': 'jalan sabang merah',
#  'gg. suro': 'gg. suropati',
#  'raya ciwari': 'raya ciwaringin',
#  'r. mar': 'r. martan',
#  'batas muara bulian': 'batas muara bulian-bat',
#  'raya pagar arca': 'raya pagar arcawin',
#  'karangs': 'karangsembung',
#  'kali anyar iv gg. 1': 'kali anyar iv, gg. 1',
#  'sut flamb iv': 'sutera flamb iv',
#  'naut': 'nautilus',
#  'raya cigugur-s': 'raya cigugur-samudra',
#  'jl. boulevard raya gading serpongtangerang': 'jl. boulevard raya gading serpong',
#  'jl. talas 2 gg. labu 1': 'jl. talas 2, gg. labu 1',
#  'dukuh menanggal dukuh': 'dukuh menan ix',
#  'kutisari sela xv': 'kutisari selatan xv',
#  'letda reta gg. xxxii': 'letda reta, gg. xxxii',
#  'med sela xxi': 'medayu sela xxi',
#  'padema ii gg. 21': 'padema ii, gg. 21',
#  'kyai sing': 'kyai singkil',
#  'kelud sela i': 'kelud selatan i',
#  'jl. ment rege': 'jl. ment regency',
#  'jl. tanah merah 4 gg. bayam': 'jl. tanah merah 4, gg. bayam',
#  'pakal pakal sumb baru gg.': 'pakal sumb baru, gg. 1',
#  'utan jati gg. d': 'utan jati, gg. d',
#  'pluit village': 'pluit indah',
#  'madr assa': 'madr assalam',
#  'raja junj lubis': 'raja junjunan lubis',
#  'kenc sari timur xii': 'kencana sari timur xii',
#  'luwun lebak': 'luwung-ge lebak',
#  'jl. komar lama gang perg': 'jl. komar lama, gang perg',
#  'ar rafi': 'wari jaya',
#  'jl. pas': 'jl. pasirk',
#  'perum mala indah': 'perumahan mala indah',
#  'tanah mer gg. sayur x': 'tanah merah, gg. sayur x',
#  'pang dip 8': 'pang dipeno 8',
#  'mas karebet': 'mas raya',
#  'rung indu 2': 'rungkut indu 2',
#  'aqu sela i': 'aquama sela i',
#  'suci gang nasim badeh': 'suci, gang nasim badeh',
#  'malang 4': 'malangbong 4',
#  'kuti sela xiii': 'kuti selatan xiii',
#  'tenggu wetan iii': 'tenggumung wetan iii',
#  'j kali baru 2 g lebar': 'j kali baru 2, g lebar',
#  'batas sub karawang-p': 'batas sub karawang-pamanukan',
#  'm a': 'mang i',
#  'candi los': 'candi losmen',
#  'rafl 7': 'raflesia 7',
#  'kapas lor gg. ii': 'kapas lor, gg. ii',
#  'a kasu': 'kasu raya',
#  'raya cibu padalarang': 'raya ciburuy padalarang',
#  'jln pega sid': 'jln pegagan sid',
#  'jodi 2': 'jodipati 2',
#  'raja raja': 'raja sela',
#  'sukam per pusk': 'sukam per puskopad',
#  'argo kencana argo merp': 'argo merp selatan i',
#  'daj timur tambel': 'daj timur tambelangan',
#  'tom raya keri': 'tom raya  keri',
#  'kemay baru gg. i': 'kemay baru, gg. i',
#  'jl. bat indah ii': 'jl. batunu indah ii',
#  'jl.sisi gg.c': 'jl.sisingama gg.c',
#  'kra pulo gg. 5': 'kra pulo, gg. 5',
#  'tebet utara i gg. staf vii': 'tebet utara i, gg. staf vii',
#  'a dam': 'pang sudi',
#  'tim 4': 'timbul 4',
#  'batu batu': 'batu perm',
#  'nurh 4': 'nurhadi 4',
#  'jl. k.h. ahmad dahl gg. iv': 'jl. k.h. ahmad dahlan, gg. iv',
#  'sinj kelod': 'sinjuana kelod',
#  'perumahan bumi pal 1': 'perumahan bumi palang 1',
#  'ment atas sela iii gg. 4': 'ment atas sela iii, gg. 4',
#  'peko i gg. 4': 'peko i, gg. 4',
#  'jl. jagal': 'jl.bal jagal',
#  'jl. lor 3': 'jl. lorong 3',
#  'pang purb': 'pangeran purb',
#  'jl. tam asri gg. dah': 'jl. tam asri, gg. dah',
#  'sepa 4c': 'sepakat 4c',
#  'a unit 29ag jalan pluit': 'jalan pluit karang ayu barat',
#  'jl cata 2': 'jl cataleya 2',
#  'rong ten': 'rong tengah',
#  'baht per 3': 'baht permai 3',
#  'may bamb sugeng': 'mayjen bamb sugeng',
#  'mitra karawang jl.mitra': 'jl.mitra utara ii',
#  'jl hid baru gg.': 'jl hid baru, gg.',
#  'utan panj iii gg. i': 'utan panj iii, gg. i',
#  'cilang': 'cilangsari',
#  'sultan salah': 'sultan salahudin',
#  'jl. raya sari': 'jl. raya sarirogo',
#  'gun per barat ii': 'gunung per barat ii',
#  'kol enjo martadi iii': 'kol enjo martadisastra iii',
#  'batas tanah karo-p': 'batas tanah karo-panji',
#  'agung agung utara 3': 'agung utara 3 a',
#  'wara iv gg. 11': 'wara iv, gg. 11',
#  'mindi raya gg. 2': 'mindi raya, gg. 2',
#  'bendu sem': 'bendungan sem',
#  'citayam par': 'citayam parung',
#  'dha hus indah timur ii': 'dharma husada indah timur ii',
#  'kapuk kapuk kebon': 'kapuk kebon jahe',
#  'tan pangkalan susu': 'tanjun pangkalan susu',
#  'pan meng': 'pan mengiat',
#  'sem jaya sela 2b': 'sem jaya selatan 2b',
#  'komp bumi putra': 'komplek bumi putra',
#  'karah karah tama asri': 'karah tama asri i',
#  'pluit pluit putri': 'pluit putri i',
#  'jl. kali tim. baru gg. lebar': 'jl. kali tim. baru, gg. lebar',
#  'h.a. rach tau lorong ki.h.a': 'h.a. rach tau lorong ki.h.abu.n',
#  'citra sur est': 'citra surodi est',
#  'jela sela 3': 'jelambar sela 3',
#  'n kom': 'jend sudi',
#  'jl. merd 98 bugel kara tange ban': 'jl. merd 98 bugel kara tange banten',
#  'tuw iii a': 'tuwowo iii a',
#  'sang utara 2': 'sanggung utara 2',
#  'alam ix': 'alamanda ix',
#  'jln raya akses tol sad': 'jln raya akses tol sadang',
#  'raya kundu': 'raya kunduran-',
#  'siliw x': 'siliwangi x',
#  'joglo joglo': 'joglo raya',
#  'jl. kali baru 2 gg. iii': 'jl. kali baru 2, gg. iii',
#  'angg i gg. lap': 'angg i, gg. lap',
#  'jl padm': 'jl padmosu',
#  'kelurahan:': 'jln raya kalimalang',
#  'griya sekar keda': 'griya sekar kedaton',
#  'pedur masjid 5': 'pedurenan masjid 5',
#  'simo mage xv gg timur': 'simo mage xv, gg timur',
#  'veteran perang kem': 'veteran perang kemerd',
#  'irig warudo': 'irig warudoyong',
#  'edel 5': 'edelweis 5',
#  'griya pamoy': 'griya pamoyanan',
#  'baruk baruk ten': 'baruk ten v',
#  'medan meda': 'medan-t tin',
#  "gg. mas jami' bai khoir": "gg. masjid jami' bai khoir",
#  'green sema mang': 'green sema mangrove',
#  'raya cima amil': 'raya cimanggu amil',
#  'syams sh': 'syamsudin sh',
#  'raya manisk': 'raya maniskidul',
#  'cipe tengah': 'cipedes tengah',
#  'jl.sematang borang.': 'jl.sematang borang',
#  'semanan semanan': 'semanan raya',
#  'danau limb barat dalam i': 'danau limboto barat dalam i',
#  'cungul geb masa': 'cungul gebang masa',
#  'bet ibu putu': 'tebet barat dalam',
#  'jl. jagir sid gg. lebar': 'jl. jagir sidomu gg. lebar',
#  'raya susuka': 'raya susukan-cia',
#  'ged batu ten iii': 'ged batu tengah iii',
#  'jl. cipinang baru 3 gg mel': 'jl. cipinang baru 3, gg mel',
#  'jl. gatot subr perum pelem per': 'jl. gatot subr perum pelem permai',
#  'este este': 'este ii',
#  'margorejo margorejo': 'margorejo indah',
#  'jl. budi luhur & gg. mas ar-r': 'jl. budi luhur &, gg. mas ar-r',
#  'jl. ban buntu ii kel': 'jl. ban buntu ii keluar',
#  'ked ii': 'kedung ii',
#  'pengadegan pengadegan timur': 'pengadegan timur raya',
#  'sabili': 'sabilillah',
#  'perum tata resid nirw': 'perumahan tata resid nirw',
#  'jln kampung rawa timur.': 'jln kampung rawa timur',
#  'mon 7': 'moncok 7',
#  'bojong rawalumbu bojong': 'bojong asri raya',
#  'sode mun': 'sodetan mun',
#  'kel. pang gang xix': 'kel. panggung gang xix',
#  'kar pandan': 'kar pandan-nga',
#  'simp sunan kalij': 'simpang sunan kalij',
#  'pacar kemb xii': 'pacar kembang xii',
#  'kec.pamekasan': 'jl.jokotole',
#  'jl.hj abdu': 'jl.hj abdullah',
#  'd - poros': 'jend ah. nasu',
#  'kober gg. kesad': 'kober, gg. kesad',
#  'a tapak': 'tapak doro',
#  'mar abd saleh': 'mar abdura saleh',
#  'rawa timur 10': 'rawajati timur 10',
#  'pat puluhan': 'patang puluhan',
#  'sam indah timur ii': 'sambik indah timur ii',
#  'grand impr sawa': 'grand impressa sawa',
#  'perm jin': 'permata jin',
#  'haji muha sya': 'haji muha syafei',
#  'jl. del v gg. 10': 'jl. del v, gg. 10',
#  'dr. kus atm': 'dr. kusuma atm',
#  'lor ilm': 'lorong ilm',
#  'wolter mongin': 'wolter monginsidi',
#  'cuc gg. 17 agus': 'cucima gg. 17 agus',
#  'lt.3swimmingpoll': 'jln.diponegoro',
#  'jem kaliba': 'jem kalibaru-ba',
#  'gajah gajah': 'gajah dem',
#  'jaga barat': 'jagalan barat',
#  'jl. sat manah i 14a': 'jl. sat manah i  14a',
#  'brat gede gg. ic': 'brat gede, gg. ic',
#  '. jl.pulau': 'jl.pulau irian',
#  'jl.citra garden city 6blok': 'jl.citra garden city 6',
#  'neg negla': 'neglasari i',
#  'rawabin iii': 'rawabinangun iii',
#  'raya mangun': 'raya mangunjaya',
#  'jl baret biru 3 yg bers 2 gg bers 2 buka:08.00- cord:6p58': 'jl baret biru 3 yg bers 2, gg bers 2 buka:08.00-20.00wib cord:6p58mr9w+7q',
#  'a no 3': 'jalan melang kaja',
#  'cijawura gir ii': 'cijawura girang ii',
#  'ranca utama': 'rancamaya utama',
#  'jl. brigj kata ruko': 'jl. brigj katamso ruko',
#  'sriwi komp rege park': 'sriwi komp regency park',
#  'gang bou': 'gang bougen',
#  'bek junc': 'bekasi junc',
#  'jen cipi asem gang mawar': 'jen cipi asem, gang mawar',
#  'gerb perum pers ban': 'gerb perum persada ban',
#  'f2)': 'jl balam',
#  'sul haji gg. hara ii': 'sul haji, gg. hara ii',
#  'dala taw kar kwa kateg taw': 'dala taw kar kwa kateguhan taw',
#  'dag': 'dagang',
#  'wara 8 gg. 10': 'wara 8, gg. 10',
#  'bulak bant lor': 'bulak banteng lor',
#  'surtik': 'surtikanti',
#  'raya kunin': 'raya kuningan-',
#  'baba sayu gg sete pasar say dari sema kanan': 'baba sayu gg sete pasar sayung dari sema kanan',
#  'jalan kapuk utarart4': 'jalan kapuk utara',
#  'r &': 'rs fatma',
#  'mah 11': 'mahoni 11',
#  'drs haji a silo': 'drs haji a silondae',
#  'r seri': 'seri 3',
#  'bak lebak': 'lebak wangi',
#  'dha bha va': 'dha bhakti va',
#  'palm spr btc & hous': 'palm spr btc & housing',
#  "h. sa'a": "h. sa'alan",
#  'sukamaj kali': 'sukamaj kalianda',
#  'pemban 2': 'pembangunan 2',
#  'citep': 'citepus-c',
#  'emb cerme': 'embong cerme',
#  'bangki': 'bangkingan',
#  'jl. kebag iv gg. buntu': 'jl. kebag iv, gg. buntu',
#  'tar 5 gg. 13': 'tar 5, gg. 13',
#  'jl. musp & gg. cem iv': 'jl. musp &, gg. cem iv',
#  'tengk mas': 'tengkulak mas',
#  'flamb golf ii': 'flamboyan golf ii',
#  'baru gg. 2': 'baru, gg. 2',
#  'sent elok ii': 'sentosa elok ii',
#  'rawa tengah gg. 6': 'rawa tengah, gg. 6',
#  'gunung anyar gunung anyar': 'gunung anyar lor iib',
#  'natr': 'natrium',
#  'menteng atas menteng': 'menteng atas dalam',
#  'serd baru 1 gg. 7': 'serd baru 1, gg. 7',
#  'sal desa bat': 'sal desa bateta',
#  'a. yani gg. iii': 'a. yani, gg. iii',
#  'sido sek gg. vii': 'sido sekola gg. vii',
#  'kali baru 2 gg. lebar': 'kali baru 2, gg. lebar',
#  'el': 'kel',
#  'jl. kramat.': 'jl. kramat',
#  'emer citra ii': 'emeralda citra ii',
#  's. lari': 's. lariang',
#  'lin pet': 'lin petapa',
#  'klam ireng': 'klampis ireng',
#  'perum green park resid': 'perumahan green park resid',
#  'kre timur': 'kremba timur',
#  'komp raya pend': 'komplek raya pend',
#  'taman bou raya': 'taman bougen raya',
#  'sisin 1': 'sisingama 1',
#  'ciku baru ciku': 'cikutra baru i',
#  'jatina': 'jatinangor-',
#  'ked raya gg. gent': 'ked raya, gg. gent',
#  'roda ii gg. mesin': 'roda ii, gg. mesin',
#  'dok suto gg. dah ii': 'doktor suto gg. dah ii',
#  'marga raya blok h2': 'margahayu raya blok h2',
#  'kapas baru gg. i': 'kapas baru, gg. i',
#  'a 6 jalan': 'jalan haji taip',
#  'simo kateru kidul': 'simo katerungan kidul',
#  'pon kel sela dalam iiic': 'pondok kel sela dalam iiic',
#  'raya pan berawa': 'raya pantai berawa',
#  'karet kuningan': 'karet pedur',
#  'peko ii g 5': 'peko ii, g 5',
#  'h zen': 'pahl rem',
#  'jl. overste isdiman.': 'jl. overste isdiman',
#  'pad 1 gang 8': 'padema 1 gang 8',
#  'telaga-su': 'telaga-sumedang',
#  'negla 2 gg. mas': 'negla 2, gg. mas',
#  'a no.3': 'jl.suka karya',
#  'bos sta': 'bos stalan',
#  'moch. kahfi sawo swad': 'moch. kahfi  sawo  swad',
#  'komp pes asri 1': 'komplek pes asri 1',
#  'tangki': 'tangkisturi',
#  'kali anyar x gg. 5': 'kali anyar x, gg. 5',
#  'udik': 'jl. akses tol cimanggis',
#  'l busana': 'let supr',
#  'teluk panj 2': 'teluk panjang 2',
#  'kh cokroa': 'kh cokroatmojo',
#  'jl jl. letj s. par': 'jl, jl. letj s. par',
#  'raya sukahaj': 'raya sukahaji-maja',
#  'bala i': 'baladewa i',
#  'jl. lan barat': 'jl. langen barat',
#  'nga jaya sela v': 'nga jaya selatan v',
#  'pem 4 gg. mas 3': 'pem 4, gg. mas 3',
#  'a villa': 'made lebah',
#  'amari cale': 'amarillis cale',
#  'johar baru utara i gg. 10': 'johar baru utara i, gg. 10',
#  'kedin lor gg. apel kedin lor': 'kedin lor, gg. apel kedin lor',
#  'ile': 'ileman',
#  'kh achmad dah': 'kh achmad dahlan',
#  'banyu urip banyu urip kid': 'banyu urip kid gg. vi',
#  'dar 4': 'darmaw 4',
#  'sig gura': 'sigura gura',
#  'sutri gg.r 2': 'sutrisno, gg.r 2',
#  'haji ung gg. a': 'haji ung, gg. a',
#  'raya pujungan-pupu': 'raya pujungan-pupuan-tabanan',
#  'jl. sed agung 2 jl. sed agung ii gg. iv': 'jl. sed agung 2 jl. sed agung ii, gg. iv',
#  'ard': 'ardagu',
#  'desa bar': 'desa barula',
#  'pul sae ii gg. pudak': 'pul sae ii, gg. pudak',
#  'kar asem gg. xiv': 'kar asem, gg. xiv',
#  'berin gg. beli': 'beringin, gg. beli',
#  'kebagusan kebag raya gg.': 'kebagusan raya, gg. buntu',
#  'jl lamo': 'jl lamongan',
#  'pari par': 'pariwi senaru-',
#  'gun lebah iii gg. i': 'gun lebah iii, gg. i',
#  'jl. rid rais perum pol ui': 'jl. rid rais perum polite ui',
#  'perm kenc i': 'permata kenc i',
#  'tunj tutur iii': 'tunjung tutur iii',
#  'mulawa sela dalam 1': 'mulawarman sela dalam 1',
#  'asr haji depan pon madi': 'asr haji depan pon madinah',
#  'komp pon punc': 'komp pondok punc',
#  'tange resid': 'tangerang resid',
#  'andi pallawa': 'andi pallawarukka',
#  'perum han kopi': 'perum handil kopi',
#  'pad i gg. 9': 'pad i, gg. 9',
#  'simp sema timur': 'simpang semanggi timur',
#  'wig sela v': 'wig selatan v',
#  'jl. tenggu wet gg. merp': 'jl. tenggumung wet gg. merp',
#  'gard indah i': 'gardenia indah i',
#  'kaw indah xvii': 'kawalu indah xvii',
#  'wonoku wetan': 'wonokusumo wetan',
#  'raya cipi': 'raya cipinang',
#  'wira per gg. pan indah': 'wira peruma gg. pan indah',
#  'jl. kebun raya cibodaskp': 'jl. kebun raya cibodas',
#  'a dan b': 'raya tlogo mas',
#  'rojo baw boro utara': 'rojo bawean boro utara',
#  'raya bedugu': 'raya bedugul-si',
#  'pa nana': 'pasar panca',
#  'jl baw': 'jl bawang',
#  'boule gad': 'boule gading',
#  'kebon baru kebon baru utara': 'kebon baru utara - d',
#  'cis wetan i': 'cisara wetan i',
#  'brat gede iii i': 'bratang gede iii i',
#  'm rava': 'ahmad yani',
#  'tep': 'tepung',
#  'pluit pluit kar molek': 'pluit kar molek xvii',
#  'jalan krisna..cebongan': 'jalan krisna',
#  'jamba v': 'jambangan v',
#  'perum panorama sepa': 'perum panorama sepatan',
#  'jl. mari': 'jl. marindal',
#  'jl. mt hary gang pln': 'jl. mt haryono, gang pln',
#  'kebon pedas i gg. mes': 'kebon pedas i, gg. mes',
#  'kam timur': 'kampus timur',
#  'sari sari indah': 'sari indah resid',
#  'sedap malam gg. i': 'sedap malam, gg. i',
#  'putat gede putat jaya barat': 'putat jaya barat vii b',
#  'jl. band pos komp wart': 'jl. band pos komp wartawan',
#  'green indust est': 'green industrial est',
#  'daya daya': 'daya raya',
#  'arab 1': 'arabika 1',
#  'kemayoran kemayoran -': 'kemayoran - budid',
#  'jln pluit karang ayu baratapartemen': 'jln pluit karang ayu barat',
#  'muti gad timur 1': 'mutiara gad timur 1',
#  'k.h. abd': 'k.h. abdura',
#  'jln.martapura lama.km': 'jln.martapura lama',
#  'gang kre sumb i': 'gang kremba sumbalan i',
#  'gang hasy': 'gang hasyimi',
#  'kong ali gg. ikhtiar': 'kong ali, gg. ikhtiar',
#  'bale arjo': 'bale arjosari',
#  'jl. karang tengah': 'jl. bona indah',
#  'ked kand gg. vii': 'ked kandang, gg. vii',
#  'duri selatan': 'duri sela',
#  'kh. sho iska': 'kh. sholeh iska',
#  'haji merin komp dpri': 'haji merin  komp dpri',
#  'bal tama sela': 'balong tama sela',
#  'gun tamp': 'gun tampomas',
#  'jl. bukit indah jl. ciu': 'jl. bukit indah jl. ciumbu',
#  'pak ran': 'pakin raya',
#  'perum puri anjas blok o': 'perumahan puri anjas blok o',
#  'jawa gg. buntu': 'jawa, gg. buntu',
#  'tan 1 gg. lang': 'tan 1, gg. lang',
#  'jl.pers raya gang amman': 'jl.pers raya, gang amman',
#  'jl. wij kus i g 12': 'jl. wij kus i, g 12',
#  'sec - tem': 'secang - tem',
#  'kepar': 'keparakan',
#  'desa ked wonokerto': 'desa kedung wonokerto',
#  'gad serp gad': 'gad serp boule',
#  'hm. joyoma': 'hm. joyomartono',
#  'res': 'resone',
#  'geri barat tanj': 'gerilya barat tanj',
#  'cipi muara iii gg. lin alam': 'cipi muara iii, gg. lin alam',
#  'jalan cia cio': 'jalan ciapus cio',
#  'jl. raya mayor oking jaya atmajaciriung': 'jl. raya mayor oking jaya atmaja',
#  'war selikur': 'warung selikur',
#  'lor sjahmi': 'lor sjahmiddin',
#  'pekanbaru-riau': 'jl sm amin',
#  'mamp prap raya gg. h. marzuki': 'mamp prap raya, gg. h. marzuki',
#  'raya binu': 'raya binuang',
#  'surowo': 'surowongso',
#  'jl. kali barat ia gg. pasar': 'jl. kali barat ia, gg. pasar',
#  'cire cire': 'cirendeu raya',
#  'ayu med utara vii': 'medayu utara vii ten',
#  'nirw est': 'nirw estate',
#  'cib indah iii': 'cibala indah iii',
#  'bor iii': 'borneo iii',
#  'jatim v griya bangun': 'jatim v griya bangunharja',
#  'siwalan per iii': 'siwalankerto permai iii',
#  'koto baru nan': 'koto baru i',
#  'mulyo utara iii': 'mulyosari utara iii',
#  'ulin gg. 6': 'ulin, gg. 6',
#  'komud supa band': 'komud supa bandung',
#  'nusa indah 2 gg. 7': 'nusa indah 2, gg. 7',
#  'keb utara': 'kebaha utara',
#  'grand mahakam resid': 'grand mahakam residence',
#  'susu kar': 'susukan kar',
#  'jl seku ujung': 'jl sekumpul ujung',
#  'ban ayu raya': 'banget ayu raya',
#  'brig raja purba': 'brig rajamin purba',
#  'haji kuj': 'haji kujang',
#  'kolo kor singaw': 'kolo kor singawinata',
#  'grand city rege': 'grand city regency',
#  'ban ii gg. 4': 'ban ii, gg. 4',
#  'derwati kel.': 'derwati mas',
#  'kem pulo gg. c2': 'kem pulo, gg. c2',
#  'prabu kiansa': 'prabu kiansantang',
#  'pangan 1': 'pangandaran 1',
#  'teuku umar gg. i': 'teuku umar, gg. i',
#  'don bosco sod': 'sodong timur 2',
#  'swa barat 17': 'swasem barat 17',
#  'ker kenc ii': 'kereta kenc ii',
#  'pang cakrab': 'pangeran cakrabuana',
#  'puradi': 'puradinata',
#  'pal xii': 'pal xiib',
#  'kalimulya': 'jl.boulevard raya kota kembang',
#  'bunga residence': 'bunga resi',
#  'pakis pakis gun': 'pakis gun 1d',
#  'jl. bojo': 'jl. bojongn',
#  'beu aceh utara': 'beureu aceh utara',
#  'suko gang i': 'sukolilo gang i',
#  'raya desa bla': 'raya desa blamba',
#  'pun pesangg 10': 'puncak pesangg 10',
#  'mua baru': 'muarar baru',
#  'buana pesangg 2': 'buana pesanggrahan 2',
#  'cemp putih barat xi gg. ii': 'cemp putih barat xi, gg. ii',
#  'banda ace pidie': 'banda aceh-b pidie',
#  'jl keta xvi': 'jl, keta xvi',
#  'ulin gg. 2': 'ulin, gg. 2',
#  'lam kra': 'lamper kra',
#  'pad 3': 'padang 3',
#  'jl. kaka': 'jl. kakatua',
#  'gur timur': 'gurame timur',
#  'komp pon indah': 'komplek pon indah',
#  'rc vet4 rc': 'rc veteran raya',
#  'send arj': 'sendang arj',
#  'wij kusuma 10': 'wijaya kusuma 10',
#  'jl.c jaya lr.1': 'jl.cila jaya lr.1',
#  'simp graha fam ii': 'simp graha family ii',
#  'kamp kem': 'kamp kemang',
#  'm kahfi 1': 'mang v, gang',
#  'pan kuw': 'pantai kuw',
#  'pondok surya mand': 'pondok surya mandala',
#  'jln gunung guntur.': 'jln gunung guntur',
#  'gar fiesta': 'garden fiesta',
#  'riau gg. h. sae': 'riau, gg. h. sae',
#  'pet melin': 'petojo melin',
#  'roro ix gang': 'roro ix, gang',
#  'jl. dono slt gang buntu': 'jl. dono slt, gang buntu',
#  'kendin lor gg. iv': 'kendin lor, gg. iv',
#  'jaya ix': 'jayagiri ix',
#  'pt bak pipe ind': 'pt bak pipe indust',
#  'kebon bawang kebon baw': 'kebon baw xv c',
#  'jl.untung suropatigg.sepakatno3rt1': 'jl.untung suropati',
#  'gurame gur': 'gurame 3',
#  'gel tump': 'gelgel tump',
#  'jl kolonel sutartojebres': 'jl kolonel sutarto',
#  'dahan kebo': 'dahan kebomas',
#  'minggujaksel': 'jln margasatwa raya',
#  'e rr dok': 'jatine timur 5',
#  'jl gal raya b12 d jakas bek': 'jl galaxy raya b12 d jakas bek',
#  'rek': 'rekson',
#  'gad indah utara 1': 'gading indah utara 1',
#  'situ pateng': 'situ patenggang',
#  'a no 28': 'jl.kampung rawa timur',
#  'au': 'austr',
#  'teru ambar gg. i': 'teru ambarawa, gg. i',
#  'rio jayo man mudo': 'rio jayo mangku mudo',
#  'pen hasil perik tra': 'pengol hasil perik tra',
#  'asem rowo asem': 'asem rowo baru',
#  'spr royal sui': 'spring royal sui',
#  'kalikep 55': 'kalikepiting 55',
#  'profe hamka': 'professor hamka',
#  'kre baru gg. i': 'kre baru, gg. i',
#  'clus kalim': 'clus kalimeris',
#  'jln mempelu.': 'jln mempelu',
#  'bint kenc': 'bint kencana',
#  'pema iii': 'pemancar iii',
#  'menur pumpungan menur': 'menur pumpu iii',
#  'e fast': 'dep amir',
#  'taman ples': 'taman plesiran',
#  'perum lembur endah': 'perumahan lembursari endah',
#  'gang keb iii': 'gang kebang iii',
#  'karet bp handi': 'karet sawah 1',
#  's.a. tirta': 's.a. tirtayasa',
#  'ten baru mulya i': 'tenggu baru mulya i',
#  'mars sela xiii': 'mars selatan xiii',
#  'irig dan raya': 'irig danita raya',
#  'e setio s pros': 'desa malalayang satu timur',
#  'pes med': 'pes medite',
#  'parung': 'parungseah',
#  'kec mel': 'kecapi mel',
#  'johar baru johar baru v': 'johar baru v, gg. rr',
#  'clus brunfe': 'clus brunfelsia',
#  'bumi lest indah tam': 'bumi lest indah tambun',
#  'karang rejo wibowo': 'karang ten xi',
#  'jalan cig rah': 'jalan cigond rah',
#  'manu bha vi': 'manukan bha vi',
#  'pri utara': 'pringg utara',
#  'tang bong vi': 'tang bongkar vi',
#  'komp hubad': 'komplek hubad',
#  'pla gg. iv': 'plampi gg. iv',
#  'bha iii gg. 1': 'bha iii, gg. 1',
#  'komp sari indah': 'kompleks sari indah',
#  'sumur mang': 'sumur manggis',
#  'katam indah 11': 'katamaran indah 11',
#  'gub ker gg. kali': 'gub kertaj gg. kali',
#  'jl. swadaya 3rt.005': 'jl. swadaya 3',
#  'pemb kpcu pakansari': 'pemba ci kpcu',
#  'cib hegar ii': 'cibeun hegar ii',
#  'altern kopi altern': 'altern cibu cileu',
#  'cipu raya gg. kemb barat': 'cipu raya, gg. kemb barat',
#  'gg. paks': 'gg. paksimas',
#  'mitra karawang(kim) jl.mitra': 'jl.mitra utara ii',
#  'kap zein ali': 'kapten zein ali',
#  'h bakri kh': 'kh wahid has',
#  'gang beri 3': 'gang beringin 3',
#  'i arief rah hak gg.': 'arief rah hak gg. tj',
#  'pes atla': 'pesona atla',
#  'komp nag per': 'kompllek nagoya per',
#  'r i barbershop': 'ir. h. jua',
#  'jl.pluit karang ayu barat.': 'jl.pluit karang ayu barat',
#  'bant teru ii gg. 7': 'bant teru ii, gg. 7',
#  'gg. abdu i': 'gg. abdullah i',
#  'dukuh kramat': 'dukuh 5',
#  'j jalan teknik': 'jalan teknik elektro',
#  'mata bumi sejah': 'mata bumi sejahtera',
#  'sil merd teng': 'sil merdeka teng',
#  'kari jawa gg warga 4': 'kari jawa, gg warga 4',
#  'pak 1 insp slipi': 'pakemb 1 insp slipi',
#  'kyai damar': 'kyai damarjati',
#  'kera sawah iii gg. 3': 'kera sawah iii, gg. 3',
#  'jl klimbu 2': 'jl klimbungan 2',
#  'l mun let': 'let jamin ginting',
#  'wij kus ii gg. 9': 'wij kus ii, gg. 9',
#  'cemp putih barat xi gg. vi': 'cemp putih barat xi, gg. vi',
#  'palem reflex palem': 'palem raja raya',
#  'pala gg. mawar': 'pala, gg. mawar',
#  'cen bund': 'cendra bund',
#  'jl.pangeran sogiri.': 'jl.pangeran sogiri',
#  'iskandarsyah iskanda': 'iskandarsyah raya',
#  'suna priyosa': 'sunandar priyosadarno',
#  'jati jati sela': 'jati sela ii',
#  'wanabh 2': 'wanabhakti 2',
#  'jalan tang bong vi': 'jalan tang bongkar vi',
#  'kandis': 'kandis-duri',
#  'jep pad': 'jep padari',
#  'gun sat': 'gun satria',
#  'raya ket': 'raya ketapa',
#  'jln lingkar selatan.': 'jln lingkar selatan',
#  'graha kali': 'graha kalimas',
#  'gang kruw 2': 'gang kruwing 2',
#  'gg. alhamdu': 'gg. alhamdulillah',
#  'jl. lak adi suci': 'jl. laksda adi suci',
#  'jl. rm kahfi 1 gg. h. dam': 'jl. rm kahfi 1, gg. h. dam',
#  'ruko delta fort': 'ruko delta fortuna',
#  'kol ahmad bad': 'kol ahmad badaru',
#  'al muzayy jalan': 'jalan tipar cak',
#  'bukit lama tk': 'bukit baru ii',
#  'ahmad ahmad': 'ahmad yani',
#  'car 1': 'caraka 1',
#  'kesad i': 'kesadaran i',
#  'simp bilu': 'simpang bilu',
#  'jl ban': 'jl bangau',
#  'pilar sela': 'pilar selatan',
#  "jl. damai raya gg. h. na'a": "jl. damai raya, gg. h. na'a",
#  'jl. ketin barat iii gg. buntu': 'jl. ketin barat iii, gg. buntu',
#  'tanah merd 7': 'tanah merdeka 7',
#  'tegal per tegal': 'tegal sari raya',
#  'jan perb temur': 'jan perbalan temur',
#  'pakal pakal barat lapa': 'pakal barat lapangan ii',
#  'kanda jaya iii': 'kandangan jaya iii',
#  'pedur jatil': 'pedur jatiluhur',
#  'amd g': 'amd, g',
#  'kesawon kalig': 'kesawon kaligandu',
#  'univer pan': 'univer pancas',
#  'tuah karya tuah': 'tuah karya ujung',
#  'gub airla vii': 'gubeng airla vii',
#  'batas lho labu': 'batas lhokse labu',
#  'bulak bulak rukem timur': 'bulak rukem timur ie',
#  'raya gondan': 'raya gondangleg',
#  'griya sut 3': 'griya sutera 3',
#  'rote raya': 'rotella raya',
#  'simo xii': 'simomag xii',
#  'jl. ass': 'jl. assyaf',
#  'lin jere maluk': 'lintas jere maluk',
#  'gunung sugih-ter besar': 'gunung sugih-terbanggi besar',
#  'dok nur iii gg. iv': 'dok nur iii, gg. iv',
#  'ger ther': 'ger theresia',
#  'agna ii': 'agnatis ii',
#  'batas kota lubuk sika': 'batas kota lubuk sikaping',
#  'firdaus)': 'jl. siak',
#  'a. pallew': 'a. pallewangi',
#  'jl.gatot subrotoperumahan': 'jl.gatot subroto',
#  'care itc': 'carefoor itc',
#  'jl. kali timur tam asri gg. i': 'jl. kali timur tam asri, gg. i',
#  'duku gg. h. asn': 'duku, gg. h. asn',
#  'mar terusan keramat': 'camar 11 7',
#  'h. mar': 'h. mardah',
#  'pin ranti 2': 'pinang ranti 2',
#  'toddo 6': 'toddopuli 6',
#  'cime raya': 'cimelati raya',
#  'a yani jend': 'jenderal ahmad yani',
#  'r. soepr': 'r. soeprapto',
#  'h usai': 'penghulu ras',
#  'jl. mal i gg. 7': 'jl. mal i, gg. 7',
#  'jl. y gg. wiro': 'jl. y, gg. wiro',
#  'wara 15 gang 16': 'wara 15, gang 16',
#  'jl. cel boule grand wisa': 'jl. celebr boule grand wisa',
#  'i.r. rais gg. v': 'i.r. rais, gg. v',
#  'ray kusu raya': 'rayung kusu raya',
#  'rung mej sela iv': 'rung mej selatan iv',
#  'jl. cim gg. kem ii': 'jl. cimunc gg. kem ii',
#  'i. gusti ngu rai g 8': 'i. gusti ngu rai, g 8',
#  'haus)': 'jl raya kresek',
#  'tem 1': 'tembak 1',
#  'sigli - kemb tanj': 'sigli - kemb tanjong',
#  'raya cio cibi': 'raya cio cibinong',
#  'laksamana mal': 'laksamana malaha',
#  'pasirm raya': 'pasirmalang raya',
#  'kem ilir gg. iii': 'kem ilir, gg. iii',
#  'gang ban utara 6': 'gang banyua utara 6',
#  'i ir.': 'ir. sut',
#  'jl. indu sela iii gg': 'jl. indu sela iii, gg',
#  'sem utara 5': 'semolo utara 5',
#  'utan jati gg. at-t': 'utan jati, gg. at-t',
#  'teru cimuncang': 'terusan cimuncang',
#  'petojo sela 7': 'petojo selatan 7',
#  'irian ser': 'irian sering',
#  'lem sukar': 'lembah sukar',
#  'raya kund - blora': 'raya kunduran - blora',
#  'i air': 'air ber',
#  'kali karang': 'kali karangsinom',
#  'bunga ram 7 gang 6': 'bunga rampai 7 gang 6',
#  'jl layar per 2c': 'jl, layar per 2c',
#  'keb timur 4': 'kebaha timur 4',
#  'raya simp bay': 'raya simp bayong',
#  'jan gg. mera': 'jan gg. meranti',
#  'swam': 'swamaha',
#  'kemakm raya': 'kemakmuran raya',
#  'jl raya lemb': 'jl raya lembang',
#  'jl raya suk': 'jl, raya suk',
#  'kalib timur lang': 'kalibutuh timur lang',
#  'limo limo': 'limo raya',
#  'lemba 3': 'lembayung 3',
#  'vija xvi': 'vijayak xvi',
#  'rm marg djojo': 'rm marg djojohadi',
#  'danau mani sela iv': 'danau maninjau sela iv',
#  'brig was kus': 'brigjen wasita kus',
#  'jln sul iska muda': 'jln sultan iska muda',
#  'kar empat timur gg. ii': 'kar empat timur, gg. ii',
#  'taman candi temb': 'taman candi tembaga',
#  'arm past': 'arm pasteur',
#  'ar rohman': 'pasar kidul',
#  'sem jaya 5 utara blok 2': 'sememi jaya 5 utara blok 2',
#  'jl. semp & gg. budi rah': 'jl. semp &, gg. budi rah',
#  'purba iv': 'purbasari iv',
#  'sawungg iii': 'sawunggaling iii',
#  'teru hang lekir iv': 'terusan hang lekir iv',
#  'jl. cip ranca': 'jl. cipamo ranca',
#  'nusa indah iv gg. 3': 'nusa indah iv, gg. 3',
#  'ked asem gg. ii': 'ked asem, gg. ii',
#  'raya han ujung aspal gg swad 2': 'raya han ujung aspal, gg swad 2',
#  'tul baw iv': 'tul bawang iv',
#  'laguna keja putih timur 1': 'laguna kejawan putih timur 1',
#  'a dinar taman': 'taman del ii',
#  'k. natawi': 'k. natawijaya',
#  'nat resid cim': 'nat residence cim',
#  'mawar merah vi gg. 2': 'mawar merah vi, gg. 2',
#  'dupak baru gg. buntu': 'dupak baru, gg. buntu',
#  'kavl p dan k pon jaya': 'kavl p dan k pondok jaya',
#  'sawah lio iv gg. 3': 'sawah lio iv, gg. 3',
#  'pesangg per 2': 'pesangg permai 2',
#  'duri pulo duri': 'duri a 1',
#  'hos cokr # 1a kereo lara': 'hos cokroam # 1a kereo lara',
#  'raya ciban ciso': 'raya ciban cisolok',
#  'bunga ram 11 gg. 3': 'bunga ram 11, gg. 3',
#  'jln abra o.ata komp perkan arfai': 'jln abra o.ata komp perkantoran arfai',
#  'yan mamo': 'yan mamoribo',
#  'martim ii': 'martimbang ii',
#  'i bukit': 'bukit batu',
#  'jl. raja iii jl. perum papan mas': 'jl. raja iii jl. perumahan papan mas',
#  'kra iii gg. 7': 'kra iii, gg. 7',
#  'wara iii gg. 4': 'wara iii, gg. 4',
#  'medokan ayu medo asri': 'medokan asri utara vii',
#  'per 4a': 'percet 4a',
#  'tebet timur tebet utara': 'tebet utara i d',
#  'perum sun selatan': 'perum sunter selatan',
#  'rw.004jatiranggon': 'jl.setiawarga 2',
#  'jl. mt hary a-1 gg. buntu': 'jl. mt hary a-1, gg. buntu',
#  'kendan gang ii': 'kendangsari gang ii',
#  'sun liat - pangkal': 'sungai liat - pangkal',
#  'pluit kel. pluit': 'pluit barat 6',
#  'gemah gemah sela': 'gemah selatan i',
#  'rambut': 'rambutan-b',
#  'mille angg': 'mille anggrek',
#  'pan 5': 'panduk 5',
#  'jl. wij kus i jl. del iv gg. 10': 'jl. wij kus i jl. del iv, gg. 10',
#  'jalan haji taip.': 'jalan haji taip',
#  'tanj binga': 'tanjung binga',
#  'raya cirebon': 'raya cirebon-tegal',
#  'dr soer tir': 'dr soer tirton',
#  'ar -': 'gar 2',
#  'kamp tanah ung': 'kamp tanah ungkuk',
#  'jl. pluit karang ayu barattower': 'jl. pluit karang ayu barat',
#  'jalan lin jambi muara bungo': 'jalan lintas jambi muara bungo',
#  'keb 7': 'kebant 7',
#  'mal vi': 'malibu vi',
#  'jl. gajah mada barat.': 'jl. gajah mada barat',
#  'wara vi gg. 17': 'wara vi, gg. 17',
#  '2.': 'jl.gatot subroto',
#  'kar klum sela': 'kar klum selatan',
#  'bakung sari gg. kre': 'bakung sari, gg. kre',
#  'pasir wari agrab': 'pasir wari agrabinta',
#  'jl. iskandar muda.no': 'jl. iskandar muda',
#  'perusa raya': 'perusahaan raya',
#  'rung industri kidul': 'rungkut industri kidul',
#  'raja sela 7': 'raja selatan 7',
#  'per neg 2 gg. uu': 'per neg 2, gg. uu',
#  'ngodang.': 'jln notojoyo',
#  'gun simr': 'gun simranda',
#  'jl. swad 3 gg. mush': 'jl. swad 3, gg. mush',
#  'kel nias': 'kelapa nias',
#  'jetis jetis mukti': 'jetis mukti vi',
#  'jl. d.i. pan gg juan': 'jl. d.i. panjai gg juan',
#  'jl. raya cibu jl. cima': 'jl. raya cibungb jl. cima',
#  'rangk jaya baru': 'rangkapan jaya baru',
#  'kemun': 'kemundung',
#  'darmaw ii d': 'darmawangsa ii d',
#  'raya cepu-b': 'raya cepu-blora',
#  'raya kal kara': 'raya kal karangbi',
#  'semolowaru semolowaru sela gg.': 'semolowaru sela gg. 13',
#  'bugel bugel mas': 'bugel mas indah',
#  'perum bukit khat 2': 'perum bukit khatuli 2',
#  'jalan taqwa mata merahdepan': 'jalan taqwa mata merah',
#  'raya tel - kosambi': 'raya telaga - kosambi',
#  'cipinang cipinang emp': 'cipinang emp barat',
#  'raya sapat tegall': 'raya sapat tegallalang',
#  'randus': 'randusongo',
#  'a kohar banyu kidul': 'banyu kidul gang v',
#  'mendr mendr': 'mendrisio 3',
#  'saliw pram': 'saliw pramono',
#  'panj jiwo gg. besar': 'panj jiwo, gg. besar',
#  'jl. k.h. zai ari': 'jl. k.h. zai arifin',
#  'ra musli': 'raya bojongsari',
#  'jl. rawa timur i gg. madr': 'jl. rawa timur i, gg. madr',
#  'jl. raya kebu': 'jl. raya kebumen',
#  'modena rege': 'modena regency',
#  'bulak bant bulak bant': 'bulak bant madya vi',
#  'kara mulya v': 'karangan mulya v',
#  'stm wal jaya gg. akur': 'stm wal jaya, gg. akur',
#  'clus peli': 'clus pelikan',
#  'utan jati gg. bocah': 'utan jati, gg. bocah',
#  'sum besar': 'sumber besar',
#  'tum suryo': 'tumeng suryo',
#  'jl. pad vi gg. 36': 'jl. pad vi, gg. 36',
#  'orla alam': 'orla utama',
#  'danau bra timur xi': 'danau bratan timur xi',
#  'jl.h siun gang ramb 1': 'jl.h siun, gang ramb 1',
#  'got roy ii': 'gotong roy ii',
#  'trim viii': 'trimezia viii',
#  'taman taman cend': 'taman cend viii',
#  'met iii': 'meteor iii',
#  'paras iv tap nauli': 'paras iv tapian nauli',
#  'jati produc': 'jati arum',
#  'send indah': 'sendang indah',
#  'jl. meditran 1': 'jl. citra raya',
#  'jl.baru underpassduren': 'jl.baru underpass',
#  'alai parak': 'alai timur',
#  'duta lest mal': 'duta lestari mal',
#  'bintara bintara': 'bintara ix',
#  'pelepah kun 2': 'pelepah kuning 2',
#  'lembu i gg. iiia': 'lembu i, gg. iiia',
#  'banjar per': 'banjar permai',
#  'ruko tange city': 'ruko tangerang city',
#  'men 8': 'menara 8',
#  'kem sari raya gg. h. bakar': 'kem sari raya, gg. h. bakar',
#  'warakas warakas gg.': 'warakas, gg. 16',
#  'par tritis 2': 'parang tritis 2',
#  'kenc wangi ix': 'kencana wangi ix',
#  'a loo aks': 'raya kebay lama',
#  'kecam kuri': 'kecam kuripan',
#  'jl. amp raya jl. c': 'jl. ampera raya jl. c',
#  'dir viii': 'dirgan viii',
#  'jln. pan': 'jln. pangan',
#  'temba rege': 'tembalang rege',
#  'ben mans': 'ben mansion',
#  'kali timur kali': 'kali timur i',
#  'gun raya gg. ar rah': 'gun raya, gg. ar rah',
#  'dal amung suta': 'dal amung sutarya',
#  'i exel': 'cipu raya',
#  'glo indah ib': 'glogor indah ib',
#  'bua dalam ii': 'buaran dalam ii',
#  'batua batua raya': 'batua raya 10',
#  'jl. rem i': 'jl. remaja i',
#  'pet - gg. mush': 'pet -, gg. mushola',
#  'raya majala': 'raya majalaya-ci',
#  'pema sela': 'pema selatan',
#  'puranaw barat': 'puranawarman barat',
#  'tanah baru tanah': 'tanah baru raya',
#  'm bekasi mayor': 'mayor madm hasi',
#  'kemanggisan kemanggisan ilir': 'kemanggisan ilir ii',
#  'puspow sela': 'puspow selatan',
#  'gembre': 'gembreng-k',
#  'wono lor baru gg. xii': 'wono lor baru, gg. xii',
#  'lampung.': 'jl.soekarno hatta',
#  'arga sumb': 'arga sumbing',
#  'perum sal nag': 'perumahan sal nag',
#  'kamp rawa lumbu': 'kampung rawa lumbu',
#  'jl. raya kal': 'jl. raya kalima',
#  'ban & dongk': 'ban & dongkelan',
#  'raya)': 'jl. adipura raya',
#  'jl. penga pes kone gg. bunga': 'jl. penga pesing kone gg. bunga',
#  'raya sitan barat': 'raya sitanggal barat',
#  'i gusti ngu rai gg. 7': 'i gusti ngu rai, gg. 7',
#  'komp pes fil': 'komp pesona fil',
#  'gang ngadine mj iii': 'gang ngadinegaran mj iii',
#  'laksa basangkasa': 'laksamana basangkasa',
#  'peneng': 'penengahan',
#  'klp': 'klp.la',
#  'garu ii b gg. setia': 'garu ii b, gg. setia',
#  'jl. sun ampal': 'jl. sungai ampal',
#  'jln raya cima gg h tohir idris': 'jln raya cimacan, gg h tohir idris',
#  'tambak medo gang 7': 'tambak medokan gang 7',
#  'gre ppi gang i': 'gre ppi, gang i',
#  'kart 17': 'kartika 17',
#  'a gg. 12': 'a, gg. 12',
#  'nagara': 'nagarawangi',
#  'wij kus iii gg. 8': 'wij kus iii, gg. 8',
#  'h m mistar cokrok': 'h m mistar cokrokusumo',
#  'johar baru 4 gang pp': 'johar baru 4, gang pp',
#  'jl. darat': 'jl.bel darat',
#  'j cema gang man': 'j cemara, gang man',
#  'utan kayujl.utan kayu': 'jl.utan kayu raya',
#  'jl cendra bun': 'jl cendrawasih bun',
#  'a 7 jalan': 'jalan sukamulya raya',
#  'mas mas jami darul': 'mas jami darul falah',
#  'tanah mas sela': 'tanah mas selatan',
#  'teru bon': 'teru bongas',
#  'swa barat vi': 'swasem barat vi',
#  'jalan pla donom xi': 'jalan pla donomulyo xi',
#  'tanj raya ii gg. suka suka': 'tanj raya ii, gg. suka suka',
#  'raya kala': 'raya kalapan',
#  'jalan karya baru.': 'jalan karya baru',
#  'sek 1 gg h. risin rt001': 'sek 1, gg h. risin rt001',
#  'jl daya raya bela kora daya biri': 'jl daya raya bela kora daya biringk',
#  'jl. perw 1 gg. amal': 'jl. perw 1, gg. amal',
#  'komar lama gg. bambu': 'komar lama, gg. bambu',
#  'komp dep per': 'komplek depart perdag',
#  'jl. rappo raya gg. i': 'jl. rappo raya, gg. i',
#  'won jaya xii': 'wonoku jaya xii',
#  'gad 2 gad': 'gad terr raya',
#  'raya pandan': 'raya pandanrejo',
#  'amur - kotamo': 'amur - kotamobagu',
#  'pel ii gg. pos ii': 'pel ii, gg. pos ii',
#  'yul usm gg. hi. amin': 'yul usman, gg. hi. amin',
#  'pun wis': 'pun wisesa',
#  'jln.nasional iiitanjakan': 'jln.nasional iii',
#  'gang poma baru ix': 'gang pomahan baru ix',
#  'capw': 'capwagen',
#  'jalan cen': 'jalan cendra',
#  'aristo': 'aristoteles',
#  'gang isti': 'gang istimewa',
#  'sid gg. iv': 'sidomu gg. iv',
#  'haji ridi gg. manam': 'haji ridi, gg. manam',
#  'stad bar': 'stadion bar',
#  'jl tume kebon awi': 'jl tumengg kebon awi',
#  'kumpulan kota lubuk sika': 'kumpulan-batas kota lubuk sika',
#  'teun daud beureueh': 'teungku daud beureueh',
#  'pauh sifat jati': 'pauh sifat jatiwar',
#  'raya cipanji-ci': 'raya cipanji-cihampelas',
#  'pangeran sang adip kuni': 'pangeran sang adip kuningan',
#  'a unit 11 ae jalan': 'jalan pluit karang ayu barat',
#  'kori pad per': 'kori pad permai',
#  'pacar keling pacar': 'pacar kel iii',
#  'jl. wono lebak': 'jl. wonorejo lebak',
#  'n lock': 'ling barat',
#  'min sari raya': 'minasa sari raya',
#  'kebon sari kos': 'kebon gang damai',
#  'cil cile': 'cile raya',
#  'jl. maruasey.': 'jl. maruasey',
#  '. lombok': 'jln. sriwijaya',
#  'raya mun kayu manis': 'raya munjul kayu manis',
#  'pondok kelapa pondok': 'pondok kel 11',
#  'il.': 'il.nom',
#  'jenderal s par v': 'jenderal s parman v',
#  'pales vii b gg.s hajar': 'pales vii b, gg.s hajar',
#  'cis kulon i': 'cisara kulon i',
#  'jl. dk gg. pandu iii': 'jl. dk, gg. pandu iii',
#  'pang bun': 'pangeran bun',
#  'jln. man work lin 4 sesu sd impr 482 pandu perum kar': 'jln. man work lingku 4 sesu sd impr 482 pandu perum kar',
#  'angke angke jaya gg.': 'angke jaya, gg. 3',
#  'ach yani 13': 'achmad yani 13',
#  'metl cile': 'metl cilengsi',
#  'haji mawa': 'haji mawardi',
#  'roro ix gg. 4': 'roro ix, gg. 4',
#  'jambi- kan': 'jambi- kandis',
#  'ban ii gg. i': 'ban ii, gg. i',
#  'mer vete': 'mergan vete',
#  'paya kum': 'paya kumbuh',
#  'perk kodam': 'perkamp kodam',
#  'desa tanj': 'desa tanjung',
#  'marga baru': 'margaluyu baru',
#  'tekno tekno': 'tekno widya',
#  'mud batu sang iv': 'muding batu sang iv',
#  'sekepa 2': 'sekepanjang 2',
#  'gang bab': 'gang babuss',
#  'dok wahi shd gg. xiiie': 'dok wahi shd, gg. xiiie',
#  'sido ii gg. 1': 'sido ii, gg. 1',
#  'jl. kont': 'jl. kontrak',
#  'gg. gun indra i': 'gg. gun indrakila i',
#  ...}

# %%
wrong_mappings = dict()

# %%
def clean_mappings(mappings):
    wrong_mappings = dict()
    correct_mappings = dict()
    
    for abbr,correct in mappings.items():
        abbr_words = abbr.split()
        correct_words = correct.split()
        red_flag = False
        
        for i in range(len(abbr_words)):
            if abbr_words[i] not in correct_words[i] or len(abbr_words)!=len(correct_words):
                red_flag = True
                break
        if red_flag:
            wrong_mappings[abbr] = correct
        else:
            correct_mappings[abbr] = correct
    return correct_mappings,wrong_mappings

# %%
correct_mappings,wrong_mappings = clean_mappings(one_to_one_mappings)

# %% [markdown]
# ## correct_mappings
# - these mappings are one to one
# - if these abbreviations are seen in our predictions we can map them to correct answer

# %%
correct_mappings
# Out:
# {'tam asri gg. 7': 'tam asri, gg. 7',
#  'ahmad dah iv': 'ahmad dahlan iv',
#  'pulori': 'puloriburit',
#  'kar utara': 'karang utara',
#  'gun anyar lor gg. i': 'gun anyar lor, gg. i',
#  'r. wol mongin': 'r. wol monginsidi',
#  'raya banjarn - pur': 'raya banjarnegara - purwok',
#  'colu ten ii': 'columbus ten ii',
#  'bule timur kel gading': 'bulevar timur kel gading',
#  'kel dua raya gg. mel': 'kel dua raya, gg. mel',
#  'jatij 2 gg. al chas iv': 'jatij 2, gg. al chas iv',
#  'prabumu': 'prabumulih-b',
#  'pad ii gg. 5': 'pad ii, gg. 5',
#  'jl. gay timur mgp': 'jl. gayung timur mgp',
#  'p. suryaa': 'p. suryaatmaja',
#  'pad ii gg. 1': 'pad ii, gg. 1',
#  'pala 2': 'palasari 2',
#  'taman crys 1': 'taman crystal 1',
#  'kra kecil': 'kramat kecil',
#  'muti lest 24': 'muti lestari 24',
#  'gran baru vi gg. vi': 'gran baru vi, gg. vi',
#  'tukad band xii': 'tukad bandung xii',
#  'mage & kutu tegal': 'magelang & kutu tegal',
#  'perum sapphire resid': 'perumahan sapphire resid',
#  'pad ii gang 17': 'padema ii gang 17',
#  'gud pel barat': 'gud peluru barat',
#  'simp pag': 'simpang pag',
#  'pon aren ii gg. sate': 'pon aren ii, gg. sate',
#  'kre bun 4': 'krekot bun 4',
#  'tang mas timur ii': 'tanggul mas timur ii',
#  'jatine kaum': 'jatinegara kaum',
#  'perintis kemerd iii': 'perintis kemerdekaan iii',
#  'jl. per neg i': 'jl. percet neg i',
#  'kamp kepu gg. vii': 'kamp kepu, gg. vii',
#  'y soed ii b': 'y soedarso ii b',
#  'raya rut': 'raya ruteng',
#  'jangli tla v': 'jangli tlawah v',
#  'p. kem iii': 'p. kemerd iii',
#  'sut flamb 6': 'sut flamboyan 6',
#  'pur iv': 'purnab iv',
#  'gad raya g 14': 'gad raya, g 14',
#  'citra yuda iv peru depok': 'citra yuda iv  peru depok',
#  'bina asih ii gg. h. kunin': 'bina asih ii, gg. h. kunin',
#  'j peg ind bar ii e': 'j pegang ind bar ii e',
#  'prof muha yamin i': 'prof muhammad yamin i',
#  'taman kahya': 'taman kahyangan',
#  'taman keba indah blok p': 'taman kebalen indah blok p',
#  'jl. jl. jend sudi': 'jl., jl. jend sudi',
#  'sut siswomi': 'sut siswomiharjo',
#  'bano ten i': 'banowati ten i',
#  'kamp hutan tua': 'kampung hutan tua',
#  'raya padang panj - buk': 'raya padang panj - bukitt',
#  'sel permai': 'selong permai',
#  'perd oti 2': 'perdatam oti 2',
#  't1 gg. tela': 't1, gg. teladan',
#  'jl. giri mekar per 3 b': 'jl. giri mekar permai 3 b',
#  'kenc utara ii': 'kencana utara ii',
#  'lap.pors gg. iii': 'lap.pors, gg. iii',
#  'tanj duren dalam 6': 'tanjung duren dalam 6',
#  'perum taman setia': 'perumahan taman setiabudi',
#  'pon muti raya ii': 'pondok muti raya ii',
#  'rawa simp 8': 'rawa simprug 8',
#  'raya mangu-bo': 'raya mangu-boyolali',
#  'putat jaya gg. lebar a': 'putat jaya, gg. lebar a',
#  'gang pen': 'gang pendid',
#  'lin sumatera kemu': 'lintas sumatera kemu',
#  'gg. suro': 'gg. suropati',
#  'raya ciwari': 'raya ciwaringin',
#  'r. mar': 'r. martan',
#  'batas muara bulian': 'batas muara bulian-bat',
#  'raya pagar arca': 'raya pagar arcawin',
#  'karangs': 'karangsembung',
#  'kali anyar iv gg. 1': 'kali anyar iv, gg. 1',
#  'sut flamb iv': 'sutera flamb iv',
#  'naut': 'nautilus',
#  'raya cigugur-s': 'raya cigugur-samudra',
#  'jl. talas 2 gg. labu 1': 'jl. talas 2, gg. labu 1',
#  'kutisari sela xv': 'kutisari selatan xv',
#  'letda reta gg. xxxii': 'letda reta, gg. xxxii',
#  'med sela xxi': 'medayu sela xxi',
#  'padema ii gg. 21': 'padema ii, gg. 21',
#  'kyai sing': 'kyai singkil',
#  'kelud sela i': 'kelud selatan i',
#  'jl. ment rege': 'jl. ment regency',
#  'jl. tanah merah 4 gg. bayam': 'jl. tanah merah 4, gg. bayam',
#  'utan jati gg. d': 'utan jati, gg. d',
#  'madr assa': 'madr assalam',
#  'raja junj lubis': 'raja junjunan lubis',
#  'kenc sari timur xii': 'kencana sari timur xii',
#  'luwun lebak': 'luwung-ge lebak',
#  'jl. komar lama gang perg': 'jl. komar lama, gang perg',
#  'jl. pas': 'jl. pasirk',
#  'perum mala indah': 'perumahan mala indah',
#  'tanah mer gg. sayur x': 'tanah merah, gg. sayur x',
#  'pang dip 8': 'pang dipeno 8',
#  'rung indu 2': 'rungkut indu 2',
#  'aqu sela i': 'aquama sela i',
#  'suci gang nasim badeh': 'suci, gang nasim badeh',
#  'malang 4': 'malangbong 4',
#  'kuti sela xiii': 'kuti selatan xiii',
#  'tenggu wetan iii': 'tenggumung wetan iii',
#  'j kali baru 2 g lebar': 'j kali baru 2, g lebar',
#  'batas sub karawang-p': 'batas sub karawang-pamanukan',
#  'candi los': 'candi losmen',
#  'rafl 7': 'raflesia 7',
#  'kapas lor gg. ii': 'kapas lor, gg. ii',
#  'raya cibu padalarang': 'raya ciburuy padalarang',
#  'jln pega sid': 'jln pegagan sid',
#  'jodi 2': 'jodipati 2',
#  'sukam per pusk': 'sukam per puskopad',
#  'daj timur tambel': 'daj timur tambelangan',
#  'tom raya keri': 'tom raya  keri',
#  'kemay baru gg. i': 'kemay baru, gg. i',
#  'jl. bat indah ii': 'jl. batunu indah ii',
#  'jl.sisi gg.c': 'jl.sisingama gg.c',
#  'kra pulo gg. 5': 'kra pulo, gg. 5',
#  'tebet utara i gg. staf vii': 'tebet utara i, gg. staf vii',
#  'tim 4': 'timbul 4',
#  'nurh 4': 'nurhadi 4',
#  'jl. k.h. ahmad dahl gg. iv': 'jl. k.h. ahmad dahlan, gg. iv',
#  'sinj kelod': 'sinjuana kelod',
#  'perumahan bumi pal 1': 'perumahan bumi palang 1',
#  'ment atas sela iii gg. 4': 'ment atas sela iii, gg. 4',
#  'peko i gg. 4': 'peko i, gg. 4',
#  'jl. jagal': 'jl.bal jagal',
#  'jl. lor 3': 'jl. lorong 3',
#  'pang purb': 'pangeran purb',
#  'jl. tam asri gg. dah': 'jl. tam asri, gg. dah',
#  'sepa 4c': 'sepakat 4c',
#  'jl cata 2': 'jl cataleya 2',
#  'rong ten': 'rong tengah',
#  'baht per 3': 'baht permai 3',
#  'may bamb sugeng': 'mayjen bamb sugeng',
#  'jl hid baru gg.': 'jl hid baru, gg.',
#  'utan panj iii gg. i': 'utan panj iii, gg. i',
#  'cilang': 'cilangsari',
#  'sultan salah': 'sultan salahudin',
#  'jl. raya sari': 'jl. raya sarirogo',
#  'gun per barat ii': 'gunung per barat ii',
#  'kol enjo martadi iii': 'kol enjo martadisastra iii',
#  'batas tanah karo-p': 'batas tanah karo-panji',
#  'wara iv gg. 11': 'wara iv, gg. 11',
#  'mindi raya gg. 2': 'mindi raya, gg. 2',
#  'bendu sem': 'bendungan sem',
#  'citayam par': 'citayam parung',
#  'dha hus indah timur ii': 'dharma husada indah timur ii',
#  'tan pangkalan susu': 'tanjun pangkalan susu',
#  'pan meng': 'pan mengiat',
#  'sem jaya sela 2b': 'sem jaya selatan 2b',
#  'komp bumi putra': 'komplek bumi putra',
#  'jl. kali tim. baru gg. lebar': 'jl. kali tim. baru, gg. lebar',
#  'h.a. rach tau lorong ki.h.a': 'h.a. rach tau lorong ki.h.abu.n',
#  'citra sur est': 'citra surodi est',
#  'jela sela 3': 'jelambar sela 3',
#  'jl. merd 98 bugel kara tange ban': 'jl. merd 98 bugel kara tange banten',
#  'tuw iii a': 'tuwowo iii a',
#  'sang utara 2': 'sanggung utara 2',
#  'alam ix': 'alamanda ix',
#  'jln raya akses tol sad': 'jln raya akses tol sadang',
#  'raya kundu': 'raya kunduran-',
#  'siliw x': 'siliwangi x',
#  'jl. kali baru 2 gg. iii': 'jl. kali baru 2, gg. iii',
#  'angg i gg. lap': 'angg i, gg. lap',
#  'jl padm': 'jl padmosu',
#  'griya sekar keda': 'griya sekar kedaton',
#  'pedur masjid 5': 'pedurenan masjid 5',
#  'simo mage xv gg timur': 'simo mage xv, gg timur',
#  'veteran perang kem': 'veteran perang kemerd',
#  'irig warudo': 'irig warudoyong',
#  'edel 5': 'edelweis 5',
#  'griya pamoy': 'griya pamoyanan',
#  "gg. mas jami' bai khoir": "gg. masjid jami' bai khoir",
#  'green sema mang': 'green sema mangrove',
#  'raya cima amil': 'raya cimanggu amil',
#  'syams sh': 'syamsudin sh',
#  'raya manisk': 'raya maniskidul',
#  'cipe tengah': 'cipedes tengah',
#  'danau limb barat dalam i': 'danau limboto barat dalam i',
#  'cungul geb masa': 'cungul gebang masa',
#  'jl. jagir sid gg. lebar': 'jl. jagir sidomu gg. lebar',
#  'raya susuka': 'raya susukan-cia',
#  'ged batu ten iii': 'ged batu tengah iii',
#  'jl. cipinang baru 3 gg mel': 'jl. cipinang baru 3, gg mel',
#  'jl. gatot subr perum pelem per': 'jl. gatot subr perum pelem permai',
#  'jl. budi luhur & gg. mas ar-r': 'jl. budi luhur &, gg. mas ar-r',
#  'jl. ban buntu ii kel': 'jl. ban buntu ii keluar',
#  'ked ii': 'kedung ii',
#  'sabili': 'sabilillah',
#  'perum tata resid nirw': 'perumahan tata resid nirw',
#  'mon 7': 'moncok 7',
#  'sode mun': 'sodetan mun',
#  'kel. pang gang xix': 'kel. panggung gang xix',
#  'kar pandan': 'kar pandan-nga',
#  'simp sunan kalij': 'simpang sunan kalij',
#  'pacar kemb xii': 'pacar kembang xii',
#  'jl.hj abdu': 'jl.hj abdullah',
#  'kober gg. kesad': 'kober, gg. kesad',
#  'mar abd saleh': 'mar abdura saleh',
#  'rawa timur 10': 'rawajati timur 10',
#  'pat puluhan': 'patang puluhan',
#  'sam indah timur ii': 'sambik indah timur ii',
#  'grand impr sawa': 'grand impressa sawa',
#  'perm jin': 'permata jin',
#  'haji muha sya': 'haji muha syafei',
#  'jl. del v gg. 10': 'jl. del v, gg. 10',
#  'dr. kus atm': 'dr. kusuma atm',
#  'lor ilm': 'lorong ilm',
#  'wolter mongin': 'wolter monginsidi',
#  'cuc gg. 17 agus': 'cucima gg. 17 agus',
#  'jem kaliba': 'jem kalibaru-ba',
#  'jaga barat': 'jagalan barat',
#  'jl. sat manah i 14a': 'jl. sat manah i  14a',
#  'brat gede gg. ic': 'brat gede, gg. ic',
#  'rawabin iii': 'rawabinangun iii',
#  'raya mangun': 'raya mangunjaya',
#  'jl baret biru 3 yg bers 2 gg bers 2 buka:08.00- cord:6p58': 'jl baret biru 3 yg bers 2, gg bers 2 buka:08.00-20.00wib cord:6p58mr9w+7q',
#  'cijawura gir ii': 'cijawura girang ii',
#  'ranca utama': 'rancamaya utama',
#  'jl. brigj kata ruko': 'jl. brigj katamso ruko',
#  'sriwi komp rege park': 'sriwi komp regency park',
#  'gang bou': 'gang bougen',
#  'bek junc': 'bekasi junc',
#  'jen cipi asem gang mawar': 'jen cipi asem, gang mawar',
#  'gerb perum pers ban': 'gerb perum persada ban',
#  'sul haji gg. hara ii': 'sul haji, gg. hara ii',
#  'dala taw kar kwa kateg taw': 'dala taw kar kwa kateguhan taw',
#  'dag': 'dagang',
#  'wara 8 gg. 10': 'wara 8, gg. 10',
#  'bulak bant lor': 'bulak banteng lor',
#  'surtik': 'surtikanti',
#  'raya kunin': 'raya kuningan-',
#  'baba sayu gg sete pasar say dari sema kanan': 'baba sayu gg sete pasar sayung dari sema kanan',
#  'mah 11': 'mahoni 11',
#  'drs haji a silo': 'drs haji a silondae',
#  'dha bha va': 'dha bhakti va',
#  'palm spr btc & hous': 'palm spr btc & housing',
#  "h. sa'a": "h. sa'alan",
#  'sukamaj kali': 'sukamaj kalianda',
#  'pemban 2': 'pembangunan 2',
#  'citep': 'citepus-c',
#  'emb cerme': 'embong cerme',
#  'bangki': 'bangkingan',
#  'jl. kebag iv gg. buntu': 'jl. kebag iv, gg. buntu',
#  'tar 5 gg. 13': 'tar 5, gg. 13',
#  'jl. musp & gg. cem iv': 'jl. musp &, gg. cem iv',
#  'tengk mas': 'tengkulak mas',
#  'flamb golf ii': 'flamboyan golf ii',
#  'baru gg. 2': 'baru, gg. 2',
#  'sent elok ii': 'sentosa elok ii',
#  'rawa tengah gg. 6': 'rawa tengah, gg. 6',
#  'natr': 'natrium',
#  'serd baru 1 gg. 7': 'serd baru 1, gg. 7',
#  'sal desa bat': 'sal desa bateta',
#  'a. yani gg. iii': 'a. yani, gg. iii',
#  'sido sek gg. vii': 'sido sekola gg. vii',
#  'kali baru 2 gg. lebar': 'kali baru 2, gg. lebar',
#  'el': 'kel',
#  'emer citra ii': 'emeralda citra ii',
#  's. lari': 's. lariang',
#  'lin pet': 'lin petapa',
#  'klam ireng': 'klampis ireng',
#  'perum green park resid': 'perumahan green park resid',
#  'kre timur': 'kremba timur',
#  'komp raya pend': 'komplek raya pend',
#  'taman bou raya': 'taman bougen raya',
#  'sisin 1': 'sisingama 1',
#  'jatina': 'jatinangor-',
#  'ked raya gg. gent': 'ked raya, gg. gent',
#  'roda ii gg. mesin': 'roda ii, gg. mesin',
#  'dok suto gg. dah ii': 'doktor suto gg. dah ii',
#  'marga raya blok h2': 'margahayu raya blok h2',
#  'kapas baru gg. i': 'kapas baru, gg. i',
#  'simo kateru kidul': 'simo katerungan kidul',
#  'pon kel sela dalam iiic': 'pondok kel sela dalam iiic',
#  'raya pan berawa': 'raya pantai berawa',
#  'peko ii g 5': 'peko ii, g 5',
#  'pad 1 gang 8': 'padema 1 gang 8',
#  'telaga-su': 'telaga-sumedang',
#  'negla 2 gg. mas': 'negla 2, gg. mas',
#  'bos sta': 'bos stalan',
#  'moch. kahfi sawo swad': 'moch. kahfi  sawo  swad',
#  'komp pes asri 1': 'komplek pes asri 1',
#  'tangki': 'tangkisturi',
#  'kali anyar x gg. 5': 'kali anyar x, gg. 5',
#  'teluk panj 2': 'teluk panjang 2',
#  'kh cokroa': 'kh cokroatmojo',
#  'jl jl. letj s. par': 'jl, jl. letj s. par',
#  'raya sukahaj': 'raya sukahaji-maja',
#  'bala i': 'baladewa i',
#  'jl. lan barat': 'jl. langen barat',
#  'nga jaya sela v': 'nga jaya selatan v',
#  'pem 4 gg. mas 3': 'pem 4, gg. mas 3',
#  'amari cale': 'amarillis cale',
#  'johar baru utara i gg. 10': 'johar baru utara i, gg. 10',
#  'kedin lor gg. apel kedin lor': 'kedin lor, gg. apel kedin lor',
#  'ile': 'ileman',
#  'kh achmad dah': 'kh achmad dahlan',
#  'dar 4': 'darmaw 4',
#  'sig gura': 'sigura gura',
#  'sutri gg.r 2': 'sutrisno, gg.r 2',
#  'haji ung gg. a': 'haji ung, gg. a',
#  'raya pujungan-pupu': 'raya pujungan-pupuan-tabanan',
#  'jl. sed agung 2 jl. sed agung ii gg. iv': 'jl. sed agung 2 jl. sed agung ii, gg. iv',
#  'ard': 'ardagu',
#  'desa bar': 'desa barula',
#  'pul sae ii gg. pudak': 'pul sae ii, gg. pudak',
#  'kar asem gg. xiv': 'kar asem, gg. xiv',
#  'berin gg. beli': 'beringin, gg. beli',
#  'jl lamo': 'jl lamongan',
#  'gun lebah iii gg. i': 'gun lebah iii, gg. i',
#  'jl. rid rais perum pol ui': 'jl. rid rais perum polite ui',
#  'perm kenc i': 'permata kenc i',
#  'tunj tutur iii': 'tunjung tutur iii',
#  'mulawa sela dalam 1': 'mulawarman sela dalam 1',
#  'asr haji depan pon madi': 'asr haji depan pon madinah',
#  'komp pon punc': 'komp pondok punc',
#  'tange resid': 'tangerang resid',
#  'andi pallawa': 'andi pallawarukka',
#  'perum han kopi': 'perum handil kopi',
#  'pad i gg. 9': 'pad i, gg. 9',
#  'simp sema timur': 'simpang semanggi timur',
#  'wig sela v': 'wig selatan v',
#  'jl. tenggu wet gg. merp': 'jl. tenggumung wet gg. merp',
#  'gard indah i': 'gardenia indah i',
#  'kaw indah xvii': 'kawalu indah xvii',
#  'wonoku wetan': 'wonokusumo wetan',
#  'raya cipi': 'raya cipinang',
#  'wira per gg. pan indah': 'wira peruma gg. pan indah',
#  'rojo baw boro utara': 'rojo bawean boro utara',
#  'raya bedugu': 'raya bedugul-si',
#  'jl baw': 'jl bawang',
#  'boule gad': 'boule gading',
#  'cis wetan i': 'cisara wetan i',
#  'brat gede iii i': 'bratang gede iii i',
#  'tep': 'tepung',
#  'jamba v': 'jambangan v',
#  'perum panorama sepa': 'perum panorama sepatan',
#  'jl. mari': 'jl. marindal',
#  'jl. mt hary gang pln': 'jl. mt haryono, gang pln',
#  'kebon pedas i gg. mes': 'kebon pedas i, gg. mes',
#  'kam timur': 'kampus timur',
#  'sedap malam gg. i': 'sedap malam, gg. i',
#  'jl. band pos komp wart': 'jl. band pos komp wartawan',
#  'green indust est': 'green industrial est',
#  'arab 1': 'arabika 1',
#  'muti gad timur 1': 'mutiara gad timur 1',
#  'k.h. abd': 'k.h. abdura',
#  'gang kre sumb i': 'gang kremba sumbalan i',
#  'gang hasy': 'gang hasyimi',
#  'kong ali gg. ikhtiar': 'kong ali, gg. ikhtiar',
#  'bale arjo': 'bale arjosari',
#  'ked kand gg. vii': 'ked kandang, gg. vii',
#  'kh. sho iska': 'kh. sholeh iska',
#  'haji merin komp dpri': 'haji merin  komp dpri',
#  'bal tama sela': 'balong tama sela',
#  'gun tamp': 'gun tampomas',
#  'jl. bukit indah jl. ciu': 'jl. bukit indah jl. ciumbu',
#  'perum puri anjas blok o': 'perumahan puri anjas blok o',
#  'jawa gg. buntu': 'jawa, gg. buntu',
#  'tan 1 gg. lang': 'tan 1, gg. lang',
#  'jl.pers raya gang amman': 'jl.pers raya, gang amman',
#  'jl. wij kus i g 12': 'jl. wij kus i, g 12',
#  'sec - tem': 'secang - tem',
#  'kepar': 'keparakan',
#  'desa ked wonokerto': 'desa kedung wonokerto',
#  'hm. joyoma': 'hm. joyomartono',
#  'res': 'resone',
#  'geri barat tanj': 'gerilya barat tanj',
#  'cipi muara iii gg. lin alam': 'cipi muara iii, gg. lin alam',
#  'jalan cia cio': 'jalan ciapus cio',
#  'war selikur': 'warung selikur',
#  'lor sjahmi': 'lor sjahmiddin',
#  'mamp prap raya gg. h. marzuki': 'mamp prap raya, gg. h. marzuki',
#  'raya binu': 'raya binuang',
#  'surowo': 'surowongso',
#  'jl. kali barat ia gg. pasar': 'jl. kali barat ia, gg. pasar',
#  'nirw est': 'nirw estate',
#  'cib indah iii': 'cibala indah iii',
#  'bor iii': 'borneo iii',
#  'jatim v griya bangun': 'jatim v griya bangunharja',
#  'siwalan per iii': 'siwalankerto permai iii',
#  'mulyo utara iii': 'mulyosari utara iii',
#  'ulin gg. 6': 'ulin, gg. 6',
#  'komud supa band': 'komud supa bandung',
#  'nusa indah 2 gg. 7': 'nusa indah 2, gg. 7',
#  'keb utara': 'kebaha utara',
#  'grand mahakam resid': 'grand mahakam residence',
#  'susu kar': 'susukan kar',
#  'jl seku ujung': 'jl sekumpul ujung',
#  'ban ayu raya': 'banget ayu raya',
#  'brig raja purba': 'brig rajamin purba',
#  'haji kuj': 'haji kujang',
#  'kolo kor singaw': 'kolo kor singawinata',
#  'grand city rege': 'grand city regency',
#  'ban ii gg. 4': 'ban ii, gg. 4',
#  'kem pulo gg. c2': 'kem pulo, gg. c2',
#  'prabu kiansa': 'prabu kiansantang',
#  'pangan 1': 'pangandaran 1',
#  'teuku umar gg. i': 'teuku umar, gg. i',
#  'swa barat 17': 'swasem barat 17',
#  'ker kenc ii': 'kereta kenc ii',
#  'pang cakrab': 'pangeran cakrabuana',
#  'puradi': 'puradinata',
#  'pal xii': 'pal xiib',
#  'jl. bojo': 'jl. bojongn',
#  'beu aceh utara': 'beureu aceh utara',
#  'suko gang i': 'sukolilo gang i',
#  'raya desa bla': 'raya desa blamba',
#  'pun pesangg 10': 'puncak pesangg 10',
#  'mua baru': 'muarar baru',
#  'buana pesangg 2': 'buana pesanggrahan 2',
#  'cemp putih barat xi gg. ii': 'cemp putih barat xi, gg. ii',
#  'banda ace pidie': 'banda aceh-b pidie',
#  'jl keta xvi': 'jl, keta xvi',
#  'ulin gg. 2': 'ulin, gg. 2',
#  'lam kra': 'lamper kra',
#  'pad 3': 'padang 3',
#  'jl. kaka': 'jl. kakatua',
#  'gur timur': 'gurame timur',
#  'komp pon indah': 'komplek pon indah',
#  'send arj': 'sendang arj',
#  'wij kusuma 10': 'wijaya kusuma 10',
#  'jl.c jaya lr.1': 'jl.cila jaya lr.1',
#  'simp graha fam ii': 'simp graha family ii',
#  'kamp kem': 'kamp kemang',
#  'pan kuw': 'pantai kuw',
#  'pondok surya mand': 'pondok surya mandala',
#  'gar fiesta': 'garden fiesta',
#  'riau gg. h. sae': 'riau, gg. h. sae',
#  'pet melin': 'petojo melin',
#  'roro ix gang': 'roro ix, gang',
#  'jl. dono slt gang buntu': 'jl. dono slt, gang buntu',
#  'kendin lor gg. iv': 'kendin lor, gg. iv',
#  'jaya ix': 'jayagiri ix',
#  'pt bak pipe ind': 'pt bak pipe indust',
#  'gel tump': 'gelgel tump',
#  'dahan kebo': 'dahan kebomas',
#  'jl gal raya b12 d jakas bek': 'jl galaxy raya b12 d jakas bek',
#  'rek': 'rekson',
#  'gad indah utara 1': 'gading indah utara 1',
#  'situ pateng': 'situ patenggang',
#  'au': 'austr',
#  'teru ambar gg. i': 'teru ambarawa, gg. i',
#  'rio jayo man mudo': 'rio jayo mangku mudo',
#  'pen hasil perik tra': 'pengol hasil perik tra',
#  'spr royal sui': 'spring royal sui',
#  'kalikep 55': 'kalikepiting 55',
#  'profe hamka': 'professor hamka',
#  'kre baru gg. i': 'kre baru, gg. i',
#  'clus kalim': 'clus kalimeris',
#  'bint kenc': 'bint kencana',
#  'pema iii': 'pemancar iii',
#  'taman ples': 'taman plesiran',
#  'perum lembur endah': 'perumahan lembursari endah',
#  'gang keb iii': 'gang kebang iii',
#  's.a. tirta': 's.a. tirtayasa',
#  'ten baru mulya i': 'tenggu baru mulya i',
#  'mars sela xiii': 'mars selatan xiii',
#  'irig dan raya': 'irig danita raya',
#  'pes med': 'pes medite',
#  'parung': 'parungseah',
#  'kec mel': 'kecapi mel',
#  'clus brunfe': 'clus brunfelsia',
#  'bumi lest indah tam': 'bumi lest indah tambun',
#  'jalan cig rah': 'jalan cigond rah',
#  'manu bha vi': 'manukan bha vi',
#  'pri utara': 'pringg utara',
#  'tang bong vi': 'tang bongkar vi',
#  'komp hubad': 'komplek hubad',
#  'pla gg. iv': 'plampi gg. iv',
#  'bha iii gg. 1': 'bha iii, gg. 1',
#  'komp sari indah': 'kompleks sari indah',
#  'sumur mang': 'sumur manggis',
#  'katam indah 11': 'katamaran indah 11',
#  'gub ker gg. kali': 'gub kertaj gg. kali',
#  'cib hegar ii': 'cibeun hegar ii',
#  'cipu raya gg. kemb barat': 'cipu raya, gg. kemb barat',
#  'gg. paks': 'gg. paksimas',
#  'kap zein ali': 'kapten zein ali',
#  'gang beri 3': 'gang beringin 3',
#  'pes atla': 'pesona atla',
#  'komp nag per': 'kompllek nagoya per',
#  'bant teru ii gg. 7': 'bant teru ii, gg. 7',
#  'gg. abdu i': 'gg. abdullah i',
#  'mata bumi sejah': 'mata bumi sejahtera',
#  'sil merd teng': 'sil merdeka teng',
#  'kari jawa gg warga 4': 'kari jawa, gg warga 4',
#  'pak 1 insp slipi': 'pakemb 1 insp slipi',
#  'kyai damar': 'kyai damarjati',
#  'kera sawah iii gg. 3': 'kera sawah iii, gg. 3',
#  'jl klimbu 2': 'jl klimbungan 2',
#  'wij kus ii gg. 9': 'wij kus ii, gg. 9',
#  'cemp putih barat xi gg. vi': 'cemp putih barat xi, gg. vi',
#  'pala gg. mawar': 'pala, gg. mawar',
#  'cen bund': 'cendra bund',
#  'suna priyosa': 'sunandar priyosadarno',
#  'wanabh 2': 'wanabhakti 2',
#  'jalan tang bong vi': 'jalan tang bongkar vi',
#  'kandis': 'kandis-duri',
#  'jep pad': 'jep padari',
#  'gun sat': 'gun satria',
#  'raya ket': 'raya ketapa',
#  'graha kali': 'graha kalimas',
#  'gang kruw 2': 'gang kruwing 2',
#  'gg. alhamdu': 'gg. alhamdulillah',
#  'jl. lak adi suci': 'jl. laksda adi suci',
#  'jl. rm kahfi 1 gg. h. dam': 'jl. rm kahfi 1, gg. h. dam',
#  'ruko delta fort': 'ruko delta fortuna',
#  'kol ahmad bad': 'kol ahmad badaru',
#  'car 1': 'caraka 1',
#  'kesad i': 'kesadaran i',
#  'simp bilu': 'simpang bilu',
#  'jl ban': 'jl bangau',
#  'pilar sela': 'pilar selatan',
#  "jl. damai raya gg. h. na'a": "jl. damai raya, gg. h. na'a",
#  'jl. ketin barat iii gg. buntu': 'jl. ketin barat iii, gg. buntu',
#  'tanah merd 7': 'tanah merdeka 7',
#  'jan perb temur': 'jan perbalan temur',
#  'kanda jaya iii': 'kandangan jaya iii',
#  'pedur jatil': 'pedur jatiluhur',
#  'amd g': 'amd, g',
#  'kesawon kalig': 'kesawon kaligandu',
#  'univer pan': 'univer pancas',
#  'gub airla vii': 'gubeng airla vii',
#  'batas lho labu': 'batas lhokse labu',
#  'raya gondan': 'raya gondangleg',
#  'griya sut 3': 'griya sutera 3',
#  'rote raya': 'rotella raya',
#  'simo xii': 'simomag xii',
#  'jl. ass': 'jl. assyaf',
#  'lin jere maluk': 'lintas jere maluk',
#  'gunung sugih-ter besar': 'gunung sugih-terbanggi besar',
#  'dok nur iii gg. iv': 'dok nur iii, gg. iv',
#  'ger ther': 'ger theresia',
#  'agna ii': 'agnatis ii',
#  'batas kota lubuk sika': 'batas kota lubuk sikaping',
#  'a. pallew': 'a. pallewangi',
#  'care itc': 'carefoor itc',
#  'jl. kali timur tam asri gg. i': 'jl. kali timur tam asri, gg. i',
#  'duku gg. h. asn': 'duku, gg. h. asn',
#  'h. mar': 'h. mardah',
#  'pin ranti 2': 'pinang ranti 2',
#  'toddo 6': 'toddopuli 6',
#  'cime raya': 'cimelati raya',
#  'r. soepr': 'r. soeprapto',
#  'jl. mal i gg. 7': 'jl. mal i, gg. 7',
#  'jl. y gg. wiro': 'jl. y, gg. wiro',
#  'wara 15 gang 16': 'wara 15, gang 16',
#  'jl. cel boule grand wisa': 'jl. celebr boule grand wisa',
#  'i.r. rais gg. v': 'i.r. rais, gg. v',
#  'ray kusu raya': 'rayung kusu raya',
#  'rung mej sela iv': 'rung mej selatan iv',
#  'jl. cim gg. kem ii': 'jl. cimunc gg. kem ii',
#  'i. gusti ngu rai g 8': 'i. gusti ngu rai, g 8',
#  'tem 1': 'tembak 1',
#  'sigli - kemb tanj': 'sigli - kemb tanjong',
#  'raya cio cibi': 'raya cio cibinong',
#  'laksamana mal': 'laksamana malaha',
#  'pasirm raya': 'pasirmalang raya',
#  'kem ilir gg. iii': 'kem ilir, gg. iii',
#  'gang ban utara 6': 'gang banyua utara 6',
#  'jl. indu sela iii gg': 'jl. indu sela iii, gg',
#  'sem utara 5': 'semolo utara 5',
#  'utan jati gg. at-t': 'utan jati, gg. at-t',
#  'teru cimuncang': 'terusan cimuncang',
#  'petojo sela 7': 'petojo selatan 7',
#  'irian ser': 'irian sering',
#  'lem sukar': 'lembah sukar',
#  'raya kund - blora': 'raya kunduran - blora',
#  'kali karang': 'kali karangsinom',
#  'bunga ram 7 gang 6': 'bunga rampai 7 gang 6',
#  'jl layar per 2c': 'jl, layar per 2c',
#  'keb timur 4': 'kebaha timur 4',
#  'raya simp bay': 'raya simp bayong',
#  'jan gg. mera': 'jan gg. meranti',
#  'swam': 'swamaha',
#  'kemakm raya': 'kemakmuran raya',
#  'jl raya lemb': 'jl raya lembang',
#  'jl raya suk': 'jl, raya suk',
#  'kalib timur lang': 'kalibutuh timur lang',
#  'lemba 3': 'lembayung 3',
#  'vija xvi': 'vijayak xvi',
#  'rm marg djojo': 'rm marg djojohadi',
#  'danau mani sela iv': 'danau maninjau sela iv',
#  'brig was kus': 'brigjen wasita kus',
#  'jln sul iska muda': 'jln sultan iska muda',
#  'kar empat timur gg. ii': 'kar empat timur, gg. ii',
#  'taman candi temb': 'taman candi tembaga',
#  'arm past': 'arm pasteur',
#  'sem jaya 5 utara blok 2': 'sememi jaya 5 utara blok 2',
#  'jl. semp & gg. budi rah': 'jl. semp &, gg. budi rah',
#  'purba iv': 'purbasari iv',
#  'sawungg iii': 'sawunggaling iii',
#  'teru hang lekir iv': 'terusan hang lekir iv',
#  'jl. cip ranca': 'jl. cipamo ranca',
#  'nusa indah iv gg. 3': 'nusa indah iv, gg. 3',
#  'ked asem gg. ii': 'ked asem, gg. ii',
#  'raya han ujung aspal gg swad 2': 'raya han ujung aspal, gg swad 2',
#  'tul baw iv': 'tul bawang iv',
#  'laguna keja putih timur 1': 'laguna kejawan putih timur 1',
#  'k. natawi': 'k. natawijaya',
#  'nat resid cim': 'nat residence cim',
#  'mawar merah vi gg. 2': 'mawar merah vi, gg. 2',
#  'dupak baru gg. buntu': 'dupak baru, gg. buntu',
#  'kavl p dan k pon jaya': 'kavl p dan k pondok jaya',
#  'sawah lio iv gg. 3': 'sawah lio iv, gg. 3',
#  'pesangg per 2': 'pesangg permai 2',
#  'hos cokr # 1a kereo lara': 'hos cokroam # 1a kereo lara',
#  'raya ciban ciso': 'raya ciban cisolok',
#  'bunga ram 11 gg. 3': 'bunga ram 11, gg. 3',
#  'jln abra o.ata komp perkan arfai': 'jln abra o.ata komp perkantoran arfai',
#  'yan mamo': 'yan mamoribo',
#  'martim ii': 'martimbang ii',
#  'jl. raja iii jl. perum papan mas': 'jl. raja iii jl. perumahan papan mas',
#  'kra iii gg. 7': 'kra iii, gg. 7',
#  'wara iii gg. 4': 'wara iii, gg. 4',
#  'per 4a': 'percet 4a',
#  'perum sun selatan': 'perum sunter selatan',
#  'jl. mt hary a-1 gg. buntu': 'jl. mt hary a-1, gg. buntu',
#  'kendan gang ii': 'kendangsari gang ii',
#  'sun liat - pangkal': 'sungai liat - pangkal',
#  'rambut': 'rambutan-b',
#  'mille angg': 'mille anggrek',
#  'pan 5': 'panduk 5',
#  'jl. wij kus i jl. del iv gg. 10': 'jl. wij kus i jl. del iv, gg. 10',
#  'tanj binga': 'tanjung binga',
#  'raya cirebon': 'raya cirebon-tegal',
#  'dr soer tir': 'dr soer tirton',
#  'kamp tanah ung': 'kamp tanah ungkuk',
#  'jalan lin jambi muara bungo': 'jalan lintas jambi muara bungo',
#  'keb 7': 'kebant 7',
#  'mal vi': 'malibu vi',
#  'wara vi gg. 17': 'wara vi, gg. 17',
#  'kar klum sela': 'kar klum selatan',
#  'bakung sari gg. kre': 'bakung sari, gg. kre',
#  'pasir wari agrab': 'pasir wari agrabinta',
#  'perusa raya': 'perusahaan raya',
#  'rung industri kidul': 'rungkut industri kidul',
#  'raja sela 7': 'raja selatan 7',
#  'per neg 2 gg. uu': 'per neg 2, gg. uu',
#  'gun simr': 'gun simranda',
#  'jl. swad 3 gg. mush': 'jl. swad 3, gg. mush',
#  'kel nias': 'kelapa nias',
#  'jl. d.i. pan gg juan': 'jl. d.i. panjai gg juan',
#  'jl. raya cibu jl. cima': 'jl. raya cibungb jl. cima',
#  'rangk jaya baru': 'rangkapan jaya baru',
#  'kemun': 'kemundung',
#  'darmaw ii d': 'darmawangsa ii d',
#  'raya cepu-b': 'raya cepu-blora',
#  'raya kal kara': 'raya kal karangbi',
#  'perum bukit khat 2': 'perum bukit khatuli 2',
#  'raya tel - kosambi': 'raya telaga - kosambi',
#  'raya sapat tegall': 'raya sapat tegallalang',
#  'randus': 'randusongo',
#  'saliw pram': 'saliw pramono',
#  'panj jiwo gg. besar': 'panj jiwo, gg. besar',
#  'jl. k.h. zai ari': 'jl. k.h. zai arifin',
#  'jl. rawa timur i gg. madr': 'jl. rawa timur i, gg. madr',
#  'jl. raya kebu': 'jl. raya kebumen',
#  'modena rege': 'modena regency',
#  'kara mulya v': 'karangan mulya v',
#  'stm wal jaya gg. akur': 'stm wal jaya, gg. akur',
#  'clus peli': 'clus pelikan',
#  'utan jati gg. bocah': 'utan jati, gg. bocah',
#  'sum besar': 'sumber besar',
#  'tum suryo': 'tumeng suryo',
#  'jl. pad vi gg. 36': 'jl. pad vi, gg. 36',
#  'danau bra timur xi': 'danau bratan timur xi',
#  'jl.h siun gang ramb 1': 'jl.h siun, gang ramb 1',
#  'got roy ii': 'gotong roy ii',
#  'trim viii': 'trimezia viii',
#  'met iii': 'meteor iii',
#  'paras iv tap nauli': 'paras iv tapian nauli',
#  'send indah': 'sendang indah',
#  'duta lest mal': 'duta lestari mal',
#  'pelepah kun 2': 'pelepah kuning 2',
#  'lembu i gg. iiia': 'lembu i, gg. iiia',
#  'banjar per': 'banjar permai',
#  'ruko tange city': 'ruko tangerang city',
#  'men 8': 'menara 8',
#  'kem sari raya gg. h. bakar': 'kem sari raya, gg. h. bakar',
#  'par tritis 2': 'parang tritis 2',
#  'kenc wangi ix': 'kencana wangi ix',
#  'kecam kuri': 'kecam kuripan',
#  'jl. amp raya jl. c': 'jl. ampera raya jl. c',
#  'dir viii': 'dirgan viii',
#  'jln. pan': 'jln. pangan',
#  'temba rege': 'tembalang rege',
#  'ben mans': 'ben mansion',
#  'gun raya gg. ar rah': 'gun raya, gg. ar rah',
#  'dal amung suta': 'dal amung sutarya',
#  'glo indah ib': 'glogor indah ib',
#  'bua dalam ii': 'buaran dalam ii',
#  'jl. rem i': 'jl. remaja i',
#  'pet - gg. mush': 'pet -, gg. mushola',
#  'raya majala': 'raya majalaya-ci',
#  'pema sela': 'pema selatan',
#  'puranaw barat': 'puranawarman barat',
#  'puspow sela': 'puspow selatan',
#  'gembre': 'gembreng-k',
#  'wono lor baru gg. xii': 'wono lor baru, gg. xii',
#  'arga sumb': 'arga sumbing',
#  'perum sal nag': 'perumahan sal nag',
#  'kamp rawa lumbu': 'kampung rawa lumbu',
#  'jl. raya kal': 'jl. raya kalima',
#  'ban & dongk': 'ban & dongkelan',
#  'jl. penga pes kone gg. bunga': 'jl. penga pesing kone gg. bunga',
#  'raya sitan barat': 'raya sitanggal barat',
#  'i gusti ngu rai gg. 7': 'i gusti ngu rai, gg. 7',
#  'komp pes fil': 'komp pesona fil',
#  'gang ngadine mj iii': 'gang ngadinegaran mj iii',
#  'laksa basangkasa': 'laksamana basangkasa',
#  'peneng': 'penengahan',
#  'klp': 'klp.la',
#  'garu ii b gg. setia': 'garu ii b, gg. setia',
#  'jl. sun ampal': 'jl. sungai ampal',
#  'jln raya cima gg h tohir idris': 'jln raya cimacan, gg h tohir idris',
#  'tambak medo gang 7': 'tambak medokan gang 7',
#  'gre ppi gang i': 'gre ppi, gang i',
#  'kart 17': 'kartika 17',
#  'a gg. 12': 'a, gg. 12',
#  'nagara': 'nagarawangi',
#  'wij kus iii gg. 8': 'wij kus iii, gg. 8',
#  'h m mistar cokrok': 'h m mistar cokrokusumo',
#  'johar baru 4 gang pp': 'johar baru 4, gang pp',
#  'jl. darat': 'jl.bel darat',
#  'j cema gang man': 'j cemara, gang man',
#  'jl cendra bun': 'jl cendrawasih bun',
#  'tanah mas sela': 'tanah mas selatan',
#  'teru bon': 'teru bongas',
#  'swa barat vi': 'swasem barat vi',
#  'jalan pla donom xi': 'jalan pla donomulyo xi',
#  'tanj raya ii gg. suka suka': 'tanj raya ii, gg. suka suka',
#  'raya kala': 'raya kalapan',
#  'sek 1 gg h. risin rt001': 'sek 1, gg h. risin rt001',
#  'jl daya raya bela kora daya biri': 'jl daya raya bela kora daya biringk',
#  'jl. perw 1 gg. amal': 'jl. perw 1, gg. amal',
#  'komar lama gg. bambu': 'komar lama, gg. bambu',
#  'komp dep per': 'komplek depart perdag',
#  'jl. rappo raya gg. i': 'jl. rappo raya, gg. i',
#  'won jaya xii': 'wonoku jaya xii',
#  'raya pandan': 'raya pandanrejo',
#  'amur - kotamo': 'amur - kotamobagu',
#  'pel ii gg. pos ii': 'pel ii, gg. pos ii',
#  'yul usm gg. hi. amin': 'yul usman, gg. hi. amin',
#  'pun wis': 'pun wisesa',
#  'gang poma baru ix': 'gang pomahan baru ix',
#  'capw': 'capwagen',
#  'jalan cen': 'jalan cendra',
#  'aristo': 'aristoteles',
#  'gang isti': 'gang istimewa',
#  'sid gg. iv': 'sidomu gg. iv',
#  'haji ridi gg. manam': 'haji ridi, gg. manam',
#  'stad bar': 'stadion bar',
#  'jl tume kebon awi': 'jl tumengg kebon awi',
#  'kumpulan kota lubuk sika': 'kumpulan-batas kota lubuk sika',
#  'teun daud beureueh': 'teungku daud beureueh',
#  'pauh sifat jati': 'pauh sifat jatiwar',
#  'raya cipanji-ci': 'raya cipanji-cihampelas',
#  'pangeran sang adip kuni': 'pangeran sang adip kuningan',
#  'kori pad per': 'kori pad permai',
#  'jl. wono lebak': 'jl. wonorejo lebak',
#  'min sari raya': 'minasa sari raya',
#  'raya mun kayu manis': 'raya munjul kayu manis',
#  'il.': 'il.nom',
#  'jenderal s par v': 'jenderal s parman v',
#  'pales vii b gg.s hajar': 'pales vii b, gg.s hajar',
#  'cis kulon i': 'cisara kulon i',
#  'jl. dk gg. pandu iii': 'jl. dk, gg. pandu iii',
#  'pang bun': 'pangeran bun',
#  'jln. man work lin 4 sesu sd impr 482 pandu perum kar': 'jln. man work lingku 4 sesu sd impr 482 pandu perum kar',
#  'ach yani 13': 'achmad yani 13',
#  'metl cile': 'metl cilengsi',
#  'haji mawa': 'haji mawardi',
#  'roro ix gg. 4': 'roro ix, gg. 4',
#  'jambi- kan': 'jambi- kandis',
#  'ban ii gg. i': 'ban ii, gg. i',
#  'mer vete': 'mergan vete',
#  'paya kum': 'paya kumbuh',
#  'perk kodam': 'perkamp kodam',
#  'desa tanj': 'desa tanjung',
#  'marga baru': 'margaluyu baru',
#  'mud batu sang iv': 'muding batu sang iv',
#  'sekepa 2': 'sekepanjang 2',
#  'gang bab': 'gang babuss',
#  'dok wahi shd gg. xiiie': 'dok wahi shd, gg. xiiie',
#  'sido ii gg. 1': 'sido ii, gg. 1',
#  'jl. kont': 'jl. kontrak',
#  'gg. gun indra i': 'gg. gun indrakila i',
#  'sul m. dja sjah': 'sultan m. dja sjah',
#  'puri nirw 21': 'puri nirwana 21',
#  'cluster ave': 'cluster avezza',
#  'kamp baru 1 gg. proka': 'kamp baru 1, gg. proka',
#  'teluk lamp': 'teluk lampung',
#  'ked agave raya': 'kedoya agave raya',
#  'jl. kamp guji gang san tam': 'jl. kamp guji, gang san tam',
#  'bint cipta h.1': 'bintara cipta h.1',
#  'jl. laksa malaha': 'jl. laksamana malaha',
#  'ngadine mj iii': 'ngadinegaran mj iii',
#  'nusa indah vi gg. 15': 'nusa indah vi, gg. 15',
#  'raya petap - ban': 'raya petap - bangki',
#  'cile jemb i': 'cilebut jembatan i',
#  'jl. batu ampar 7 gang': 'jl. batu ampar 7, gang',
#  'raya inp purwo': 'raya inp purwojati',
#  'ruko rumb pasur': 'ruko rumbung pasur',
#  'sut sism': 'sut sismowi',
#  'pamula barat vi': 'pamularsih barat vi',
#  'tulo bawah viii': 'tulodong bawah viii',
#  'kra jaya baru gg. v': 'kra jaya baru, gg. v',
#  'kra pulo gg. vii': 'kra pulo, gg. vii',
#  'raya pad pai': 'raya pad painan',
#  'susu': 'susukan',
#  'raya bas': 'raya basang',
#  'gg mas dar terus ada belo gg nan ke kanan': 'gg mas daruss terus ada belo gg nan ke kanan',
#  'peko 1 gg. 1': 'peko 1, gg. 1',
#  'kend rejo gg. 1f': 'kend rejo, gg. 1f',
#  'raya pany': 'raya panying',
#  'ulin gg. 5': 'ulin, gg. 5',
#  'keku gg. del': 'keku gg. delman',
#  'mer x': 'merbau x',
#  'jl. pahl unit 2 sblh kiri': 'jl. pahlawan unit 2 sblh kiri',
#  'jojo stal': 'jojoran stal',
#  'desa ked hal': 'desa ked halang',
#  'jl.k nurs dep tiku makam keta': 'jl.k nurs dep tiku makam ketangg',
#  'andi mallar': 'andi mallarangen',
#  'perum pes par': 'perum pesona parahy',
#  'bukit aka': 'bukit akasia',
#  'rung mej sela iii': 'rungkut mej sela iii',
#  'raden inten ii gang. pulo ii': 'raden inten ii, gang. pulo ii',
#  'prapa': 'prapat-ti',
#  'gg. sent 1': 'gg. sentosa 1',
#  'danau bra iii': 'danau bratan iii',
#  'joyo tambak': 'joyo tambaksari',
#  'sut kir 1': 'sut kirana 1',
#  'jl.moh': 'jl.moh.toha',
#  'boe ii': 'boeing ii',
#  'wis ban': 'wis banyum',
#  'kuti indah sela i': 'kuti indah selatan i',
#  'anug grafika resid': 'anug grafika residence',
#  'lapa pors gg. iv': 'lapa pors, gg. iv',
#  'ruko borob agung': 'ruko borobudur agung',
#  'pan losi': 'pantai losi',
#  'mun ii': 'munaww ii',
#  'dok makal gg. 1': 'dokter makal gg. 1',
#  'r. tum hardiwi': 'r. tumeng hardiwi',
#  'bet 5': 'betung 5',
#  'baing marj': 'baing marjuki',
#  'pad luar-b kota bukitt': 'pad luar-batas kota bukittinggi',
#  'desa mon lapp': 'desa moncon lapp',
#  'gg. dalam mach': 'gg. dalam machsan',
#  'tam dalam baru gg. iv': 'tam dalam baru, gg. iv',
#  'kawa wis ijen': 'kawasan wis ijen',
#  'mongon baru': 'mongonsidi baru',
#  'merc benz gang mont': 'merc benz, gang mont',
#  'kra pulo gg. 9': 'kra pulo, gg. 9',
#  'dip lor 7': 'dip lorong 7',
#  'blangk cane': 'blangkejer cane',
#  'sat squ': 'satria squ',
#  'bunga ram vii gg. 4': 'bunga ram vii, gg. 4',
#  'man besar 2': 'mangga besar 2',
#  'ber iii gg. mas': 'ber iii, gg. mas',
#  "k.h. sa'": "k.h. sa'ban",
#  'wiy gang tama bha': 'wiy gang tama bhakti',
#  'per jaya per': 'periuk jaya per',
#  'swasem barat 14': 'swasembada barat 14',
#  'sem jaya gg. iia': 'sem jaya, gg. iia',
#  'raya peta': 'raya petang-',
#  'suk cika': 'sukapa cika',
#  'kemb kencana gg. mas': 'kemb kencana, gg. mas',
#  'samas war mulyo bamb lip': 'samas warung mulyo bamb lip',
#  'sindu ii': 'sindujoyo ii',
#  'indu ii gg': 'indu ii, gg',
#  'keda 7': 'kedasih 7',
#  'matr dalam ii gg. vii': 'matr dalam ii, gg. vii',
#  'pad iv': 'padema iv',
#  'sut oli 16': 'sutera oli 16',
#  'mak 3': 'makmur 3',
#  'raya sed lawas': 'raya sedayu lawas',
#  'taman sent blok e': 'taman sentosa blok e',
#  'rung lor gg. x': 'rung lor, gg. x',
#  'kam uni muhamma': 'kam univer muhammadiyah',
#  'perum wisma cakra': 'perumahan wisma cakra',
#  'peko iii gg. 6': 'peko iii, gg. 6',
#  'raya penu': 'raya penujak',
#  'pesangg raya': 'pesanggrahan raya',
#  'pun pesa 3': 'pun pesangg 3',
#  'bulak bant lor gg. iv': 'bulak bant lor, gg. iv',
#  'sindu gang 11': 'sindujoyo gang 11',
#  'pagesa iv': 'pagesangan iv',
#  'dewi sart gang lang': 'dewi sartika gang lang',
#  'ran rege ii': 'rancam rege ii',
#  'taman sen ii': 'taman sengka ii',
#  'wono baru barat iv': 'wonodri baru barat iv',
#  'gang gg. pang surya i': 'gang, gg. pang surya i',
#  'perum depok maharaja': 'perumahan depok maharaja',
#  'raya cijen': 'raya cijengkol',
#  'kel kop barat 4': 'kelapa kop barat 4',
#  'raya labu lombok': 'raya labuhan lombok',
#  'tam sir 6': 'tampak sir 6',
#  'raya sukawe': 'raya sukawening',
#  'jl. pad timur iv gg. 23': 'jl. pad timur iv, gg. 23',
#  'jl. ais nasu': 'jl. ais nasution',
#  'jl. h. jian gg. anggur': 'jl. h. jian, gg. anggur',
#  'perum villa palem': 'perumahan villa palem',
#  'kra kosa 2': 'kramat kosa 2',
#  'jela utama 3': 'jelambar utama 3',
#  'muti citra aps 15': 'muti citra aps  15',
#  'bros': 'brosot-',
#  'jemb lamp': 'jembatan lamp',
#  'tanj aur': 'tanjung aur',
#  'pakis tirto ix': 'pakis tirtosari ix',
#  'kap soe djojo': 'kap soebij djojo',
#  'jl inuk': 'jl inukert',
#  'sut lave park 4': 'sutera lave park 4',
#  'jl. ulin gang 3': 'jl. ulin, gang 3',
#  'vete gg. ix': 'veteran, gg. ix',
#  'sur barat v': 'suromu barat v',
#  'pati-g': 'pati-gabus',
#  'jen cipi asem gg. tim': 'jen cipi asem, gg. tim',
#  'swad utama': 'swadaya utama',
#  'desa peg': 'desa pegadu',
#  'kecu 9': 'kecubung 9',
#  'simp sud 1': 'simpang sudima 1',
#  'pemban ii': 'pembangunan ii',
#  'mad ii': 'madyot ii',
#  'jela sela 15': 'jelambar sela 15',
#  'taman cina': 'taman cinangka',
#  'pon ser iv': 'pondok ser iv',
#  'jl.k sela v': 'jl.keru sela v',
#  'darmaw berun jaya': 'darmaw beruntung jaya',
#  'kra blen': 'kramat blen',
#  'k h abdura wahid': 'k h abdurahman wahid',
#  'perum puri cika asri': 'perum puri cikarang asri',
#  'ketin baru vii': 'ketintang baru vii',
#  'adminis 2': 'administrasi 2',
#  'duri sela iii gg. iii': 'duri sela iii, gg. iii',
#  'jl. s.t mauj': 'jl. s.t.n. mauj',
#  'lin banko-k': 'lintas banko-k',
#  'dharmaw dalam': 'dharmawangsa dalam',
#  'kel - kar': 'kel - karang',
#  'duri kepa raya gg. e': 'duri kepa raya, gg. e',
#  'prof. mun hit': 'prof. munzir hit',
#  'moch toha gg. muda': 'moch toha, gg. muda',
#  'raya alasgu': 'raya alasgung-su',
#  'male karangtengah': 'maleber karangtengah',
#  'man kart': 'man kartika',
#  'per neg 2 gang nav': 'per neg 2, gang nav',
#  'bts. kampar': 'bts. kampar-ban',
#  'jl. raya jat timur': 'jl. raya jatine timur',
#  'rusu jamso': 'rusunawa jamso',
#  'wanahe cik': 'wanaherang cik',
#  'raya bojongg': 'raya bojonggambir',
#  'cig gir': 'cigond gir',
#  'monj blun gede 40': 'monj blunyah gede 40',
#  'perum bukit gad residence': 'perum bukit gading residence',
#  'kebon jahe gg mas lapa satu': 'kebon jahe, gg masjid lapa satu',
#  'dukuh kup barat i gg. buntu': 'dukuh kup barat i, gg. buntu',
#  'dip ukur gg. karya 2': 'dip ukur, gg. karya 2',
#  'pangu': 'pangurura',
#  'angke jaya gg. 3': 'angke jaya, gg. 3',
#  'cemp putih ten 4': 'cemp putih tengah 4',
#  'wara v gg. 1': 'wara v, gg. 1',
#  'kyai goz': 'kyai gozali',
#  'raya ters': 'raya tersono',
#  'raya mani bas': 'raya maninjau bas',
#  'raya kop timur': 'raya kopang timur',
#  'kh. abd wahid': 'kh. abdurr wahid',
#  'papar': 'papar-',
#  'dukuh ping 2': 'dukuh pinggir 2',
#  'pariwi pan kuta': 'pariwi pantai kuta',
#  'perum bumi kenc': 'perum bumi kencana',
#  'pes bumya': 'pesona bumya',
#  'peno': 'penompo',
#  'jatibe raya 2': 'jatibening raya 2',
#  'pot': 'potrek',
#  'byp kut': 'byp kuta-a',
#  'poros tan': 'poros tanget',
#  'jalan sisingama': 'jalan sisingamangaraja',
#  'gg. al-m': 'gg. al-muha',
#  'villa jatipa': 'villa jatipadang',
#  'dewi sart xii': 'dewi sartika xii',
#  'bak sari gg. bid': 'bak sari, gg. bid',
#  'sawu sela ii': 'sawungg sela ii',
#  'rh fisa': 'rh fisabil',
#  'kh abd wahid': 'kh abdura wahid',
#  'k h has ashari': 'k h hasyim ashari',
#  'pad 4 gg. 11': 'pad 4, gg. 11',
#  'kh. gg. kelu': 'kh.sya gg. kelu',
#  'jl bakri ent pemb hulu i': 'jl bakri ent pembuang hulu i',
#  'west summer': 'west summerland',
#  'kart viii b': 'kartika viii b',
#  'dep iii': 'depsos iii',
#  'kremba jaya utara gang vi': 'krembangan jaya utara gang vi',
#  'sum lest': 'sum lestari',
#  'kalioso': 'kalioso-simo',
#  'komp mer mas': 'kompleks mer mas',
#  'desa kepuh kem': 'desa kepuh kemiri',
#  'alt cibubur cileu': 'alt cibubur cileungsi',
#  'kar mate': 'karang mate',
#  'masy gad mas': 'masy gading mas',
#  ...}

# %%
len(correct_mappings)
# Out:
# 47022

# %%
import pickle
with open(r"C:\Users\tanch\Documents\Coding Competitions\Shopee\Shopee Address Elements Extraction (local)\datasets\Abbr_to_Norm_mappings.pickle","wb") as f:
    pickle.dump(correct_mappings,f)

# %% [markdown]
# - below are wrong mappings which we wont use

# %%
(wrong_mappings)
# Out:
# {'pluit pluit karang jel': 'pluit karang jel 13',
#  'cipinang besar selatan': 'cipinang jaya 1a',
#  'gesya gesya': 'gesya resid',
#  'sungai beringin': 'sungai beri',
#  'mamp 2nd': 'mamp prap',
#  'al maqbul (jalan': 'jalan raya kuwolu',
#  'jl. mh. thamrin.': 'jl. mh. thamrin',
#  'jl pluit karang ayu baratpenjaringanjkt': 'jl pluit karang ayu barat',
#  'indra indra jaya gang': 'indra jaya gang ten',
#  'ploso kel. ploso': 'ploso timur iv',
#  'sira siraman': 'siraman pulu',
#  'pulo padang pulo pad': 'pulo pad - mar',
#  'l no 17': 'jl. syarifuddin yoes',
#  'kalbar': 'jln.ngura',
#  'punia)': 'jl. sriwijaya',
#  'jalan sabang merahkelurahan': 'jalan sabang merah',
#  'jl. boulevard raya gading serpongtangerang': 'jl. boulevard raya gading serpong',
#  'dukuh menanggal dukuh': 'dukuh menan ix',
#  'pakal pakal sumb baru gg.': 'pakal sumb baru, gg. 1',
#  'pluit village': 'pluit indah',
#  'ar rafi': 'wari jaya',
#  'mas karebet': 'mas raya',
#  'm a': 'mang i',
#  'a kasu': 'kasu raya',
#  'raja raja': 'raja sela',
#  'argo kencana argo merp': 'argo merp selatan i',
#  'a dam': 'pang sudi',
#  'batu batu': 'batu perm',
#  'a unit 29ag jalan pluit': 'jalan pluit karang ayu barat',
#  'mitra karawang jl.mitra': 'jl.mitra utara ii',
#  'agung agung utara 3': 'agung utara 3 a',
#  'kapuk kapuk kebon': 'kapuk kebon jahe',
#  'karah karah tama asri': 'karah tama asri i',
#  'pluit pluit putri': 'pluit putri i',
#  'n kom': 'jend sudi',
#  'joglo joglo': 'joglo raya',
#  'kelurahan:': 'jln raya kalimalang',
#  'baruk baruk ten': 'baruk ten v',
#  'medan meda': 'medan-t tin',
#  'jl.sematang borang.': 'jl.sematang borang',
#  'semanan semanan': 'semanan raya',
#  'bet ibu putu': 'tebet barat dalam',
#  'este este': 'este ii',
#  'margorejo margorejo': 'margorejo indah',
#  'pengadegan pengadegan timur': 'pengadegan timur raya',
#  'jln kampung rawa timur.': 'jln kampung rawa timur',
#  'bojong rawalumbu bojong': 'bojong asri raya',
#  'kec.pamekasan': 'jl.jokotole',
#  'd - poros': 'jend ah. nasu',
#  'a tapak': 'tapak doro',
#  'lt.3swimmingpoll': 'jln.diponegoro',
#  'gajah gajah': 'gajah dem',
#  '. jl.pulau': 'jl.pulau irian',
#  'jl.citra garden city 6blok': 'jl.citra garden city 6',
#  'neg negla': 'neglasari i',
#  'a no 3': 'jalan melang kaja',
#  'f2)': 'jl balam',
#  'jalan kapuk utarart4': 'jalan kapuk utara',
#  'r &': 'rs fatma',
#  'r seri': 'seri 3',
#  'bak lebak': 'lebak wangi',
#  'gunung anyar gunung anyar': 'gunung anyar lor iib',
#  'menteng atas menteng': 'menteng atas dalam',
#  'jl. kramat.': 'jl. kramat',
#  'ciku baru ciku': 'cikutra baru i',
#  'a 6 jalan': 'jalan haji taip',
#  'karet kuningan': 'karet pedur',
#  'h zen': 'pahl rem',
#  'jl. overste isdiman.': 'jl. overste isdiman',
#  'a no.3': 'jl.suka karya',
#  'udik': 'jl. akses tol cimanggis',
#  'l busana': 'let supr',
#  'a villa': 'made lebah',
#  'banyu urip banyu urip kid': 'banyu urip kid gg. vi',
#  'kebagusan kebag raya gg.': 'kebagusan raya, gg. buntu',
#  'pari par': 'pariwi senaru-',
#  'jl. kebun raya cibodaskp': 'jl. kebun raya cibodas',
#  'a dan b': 'raya tlogo mas',
#  'pa nana': 'pasar panca',
#  'kebon baru kebon baru utara': 'kebon baru utara - d',
#  'm rava': 'ahmad yani',
#  'pluit pluit kar molek': 'pluit kar molek xvii',
#  'jalan krisna..cebongan': 'jalan krisna',
#  'sari sari indah': 'sari indah resid',
#  'putat gede putat jaya barat': 'putat jaya barat vii b',
#  'daya daya': 'daya raya',
#  'kemayoran kemayoran -': 'kemayoran - budid',
#  'jln pluit karang ayu baratapartemen': 'jln pluit karang ayu barat',
#  'jln.martapura lama.km': 'jln.martapura lama',
#  'jl. karang tengah': 'jl. bona indah',
#  'duri selatan': 'duri sela',
#  'pak ran': 'pakin raya',
#  'gad serp gad': 'gad serp boule',
#  'jl. raya mayor oking jaya atmajaciriung': 'jl. raya mayor oking jaya atmaja',
#  'pekanbaru-riau': 'jl sm amin',
#  'cire cire': 'cirendeu raya',
#  'ayu med utara vii': 'medayu utara vii ten',
#  'koto baru nan': 'koto baru i',
#  'derwati kel.': 'derwati mas',
#  'don bosco sod': 'sodong timur 2',
#  'kalimulya': 'jl.boulevard raya kota kembang',
#  'bunga residence': 'bunga resi',
#  'pakis pakis gun': 'pakis gun 1d',
#  'rc vet4 rc': 'rc veteran raya',
#  'm kahfi 1': 'mang v, gang',
#  'jln gunung guntur.': 'jln gunung guntur',
#  'kebon bawang kebon baw': 'kebon baw xv c',
#  'jl.untung suropatigg.sepakatno3rt1': 'jl.untung suropati',
#  'gurame gur': 'gurame 3',
#  'jl kolonel sutartojebres': 'jl kolonel sutarto',
#  'minggujaksel': 'jln margasatwa raya',
#  'e rr dok': 'jatine timur 5',
#  'a no 28': 'jl.kampung rawa timur',
#  'asem rowo asem': 'asem rowo baru',
#  'jln mempelu.': 'jln mempelu',
#  'menur pumpungan menur': 'menur pumpu iii',
#  'e fast': 'dep amir',
#  'karet bp handi': 'karet sawah 1',
#  'e setio s pros': 'desa malalayang satu timur',
#  'johar baru johar baru v': 'johar baru v, gg. rr',
#  'karang rejo wibowo': 'karang ten xi',
#  'jl. swadaya 3rt.005': 'jl. swadaya 3',
#  'pemb kpcu pakansari': 'pemba ci kpcu',
#  'altern kopi altern': 'altern cibu cileu',
#  'mitra karawang(kim) jl.mitra': 'jl.mitra utara ii',
#  'h bakri kh': 'kh wahid has',
#  'i arief rah hak gg.': 'arief rah hak gg. tj',
#  'r i barbershop': 'ir. h. jua',
#  'jl.pluit karang ayu barat.': 'jl.pluit karang ayu barat',
#  'dukuh kramat': 'dukuh 5',
#  'j jalan teknik': 'jalan teknik elektro',
#  'l mun let': 'let jamin ginting',
#  'palem reflex palem': 'palem raja raya',
#  'jl.pangeran sogiri.': 'jl.pangeran sogiri',
#  'iskandarsyah iskanda': 'iskandarsyah raya',
#  'jati jati sela': 'jati sela ii',
#  'jln lingkar selatan.': 'jln lingkar selatan',
#  'al muzayy jalan': 'jalan tipar cak',
#  'bukit lama tk': 'bukit baru ii',
#  'ahmad ahmad': 'ahmad yani',
#  'tegal per tegal': 'tegal sari raya',
#  'pakal pakal barat lapa': 'pakal barat lapangan ii',
#  'tuah karya tuah': 'tuah karya ujung',
#  'bulak bulak rukem timur': 'bulak rukem timur ie',
#  'firdaus)': 'jl. siak',
#  'jl.gatot subrotoperumahan': 'jl.gatot subroto',
#  'mar terusan keramat': 'camar 11 7',
#  'a yani jend': 'jenderal ahmad yani',
#  'h usai': 'penghulu ras',
#  'haus)': 'jl raya kresek',
#  'i ir.': 'ir. sut',
#  'i air': 'air ber',
#  'limo limo': 'limo raya',
#  'ar rohman': 'pasar kidul',
#  'a dinar taman': 'taman del ii',
#  'duri pulo duri': 'duri a 1',
#  'i bukit': 'bukit batu',
#  'medokan ayu medo asri': 'medokan asri utara vii',
#  'tebet timur tebet utara': 'tebet utara i d',
#  'rw.004jatiranggon': 'jl.setiawarga 2',
#  'pluit kel. pluit': 'pluit barat 6',
#  'gemah gemah sela': 'gemah selatan i',
#  'jalan haji taip.': 'jalan haji taip',
#  'ar -': 'gar 2',
#  'jl. pluit karang ayu barattower': 'jl. pluit karang ayu barat',
#  'jl. gajah mada barat.': 'jl. gajah mada barat',
#  '2.': 'jl.gatot subroto',
#  'jl. iskandar muda.no': 'jl. iskandar muda',
#  'ngodang.': 'jln notojoyo',
#  'jetis jetis mukti': 'jetis mukti vi',
#  'semolowaru semolowaru sela gg.': 'semolowaru sela gg. 13',
#  'bugel bugel mas': 'bugel mas indah',
#  'jalan taqwa mata merahdepan': 'jalan taqwa mata merah',
#  'cipinang cipinang emp': 'cipinang emp barat',
#  'a kohar banyu kidul': 'banyu kidul gang v',
#  'mendr mendr': 'mendrisio 3',
#  'ra musli': 'raya bojongsari',
#  'bulak bant bulak bant': 'bulak bant madya vi',
#  'orla alam': 'orla utama',
#  'taman taman cend': 'taman cend viii',
#  'jati produc': 'jati arum',
#  'jl. meditran 1': 'jl. citra raya',
#  'jl.baru underpassduren': 'jl.baru underpass',
#  'alai parak': 'alai timur',
#  'bintara bintara': 'bintara ix',
#  'warakas warakas gg.': 'warakas, gg. 16',
#  'a loo aks': 'raya kebay lama',
#  'kali timur kali': 'kali timur i',
#  'i exel': 'cipu raya',
#  'batua batua raya': 'batua raya 10',
#  'tanah baru tanah': 'tanah baru raya',
#  'm bekasi mayor': 'mayor madm hasi',
#  'kemanggisan kemanggisan ilir': 'kemanggisan ilir ii',
#  'lampung.': 'jl.soekarno hatta',
#  'raya)': 'jl. adipura raya',
#  'utan kayujl.utan kayu': 'jl.utan kayu raya',
#  'a 7 jalan': 'jalan sukamulya raya',
#  'mas mas jami darul': 'mas jami darul falah',
#  'jalan karya baru.': 'jalan karya baru',
#  'gad 2 gad': 'gad terr raya',
#  'jln.nasional iiitanjakan': 'jln.nasional iii',
#  'a unit 11 ae jalan': 'jalan pluit karang ayu barat',
#  'pacar keling pacar': 'pacar kel iii',
#  'n lock': 'ling barat',
#  'kebon sari kos': 'kebon gang damai',
#  'cil cile': 'cile raya',
#  'jl. maruasey.': 'jl. maruasey',
#  '. lombok': 'jln. sriwijaya',
#  'pondok kelapa pondok': 'pondok kel 11',
#  'angke angke jaya gg.': 'angke jaya, gg. 3',
#  'tekno tekno': 'tekno widya',
#  'babakan ciparay': 'babakan cipa',
#  'muara enim muara enim-si': 'muara enim-si sugih waras',
#  'no.2': 'jalan kruing 3',
#  'setia budi setia budi': 'setia budi timur 4',
#  'pacar keling pacar kel vi': 'pacar kel vi pasar c',
#  'm hayam': 'hayam wuruk',
#  'e desa kamp': 'desa kamp baru',
#  'bulak bulak rukem': 'bulak rukem timur',
#  'sidotopo sidotopo sek gg.': 'sidotopo sekola gg. vii',
#  'bulak bulak setro utara': 'bulak setro utara ii',
#  'kar ten kar': 'kar ten raya',
#  'pon gede pon': 'pon gede plaza',
#  'merek merek-bts.': 'merek-bts. dairi',
#  'petemon petemon': 'petemon iii',
#  'purwo sari mush': 'purwo gang 2',
#  'baji mappakasunggu': 'baji dakka',
#  'jemur wonosari kel.': 'jemur anda xv',
#  'jalan gatot subrotoperumahan': 'jalan gatot subroto',
#  'kuin selatan': 'kuin sela',
#  'r peri': 'perintis kemerd',
#  'jalan indrayasawarung': 'jalan indrayasa',
#  'jl. ahmad yani.': 'jl. ahmad yani',
#  'dupak dupak ban gg.': 'dupak ban gg. ii',
#  'petamburan petamburan': 'petamburan iv',
#  'tril tril': 'tril vi',
#  'sutorejo suto ten': 'sutorejo ten v',
#  'setra setra sari': 'setra sari ten',
#  'jagakarsa jagak': 'jagakarsa raya',
#  'dan tra medan': 'medan merd timur',
#  'a kap a': 'kap a hasan',
#  'i setia': 'setia jadi',
#  'gili gili': 'gili trawa',
#  'agung agung perkasa': 'agung perkasa raya',
#  'wiy wiy indah': 'wiy indah vi',
#  'serua serua': 'serua per',
#  'cawas queen': 'cawas tawang',
#  'jl pemuda.': 'jl pemuda',
#  'ma lelo': 'gramapuri taman',
#  'pluit pluit putra': 'pluit putra kenc',
#  'jl.pelita vi': 'jl.pelita iv',
#  '54.601.81': 'jalan dinoyo',
#  'd gypsum': 'abdul wahab',
#  'gub gub kerta': 'gub kertajaya xi',
#  'jl.gunung soputan.pertokoan': 'jl.gunung soputan',
#  'karet semanggi': 'karet sawah',
#  'putra kepu panj': 'keputran panj 2',
#  'no.6)': 'jalan aria putra',
#  'bulak bulak setro': 'bulak setro iv',
#  'se selo mulyo mukti timur': 'selo mulyo mukti timur 1',
#  'jl. gedung grha mp': 'jl. kemanggisan ilir raya',
#  'lagoa lagoa': 'lagoa b',
#  'ibu yuli': 'ibu gani',
#  'jl. 17 agustuscasa': 'jl. 17 agustus',
#  'ragajaya': 'jalan duren baru',
#  'l no 2': 'jl. tropodo i',
#  'bonto bonto duri': 'bonto duri 7',
#  'ploso ploso timur i': 'ploso timur i a',
#  '45)': 'jl rajawali baru',
#  'galur galur': 'galur sela',
#  'duren tiga duren': 'duren tiga raya',
#  'tanjung 135': 'tanjung datuk',
#  '. sego soto': 'jl. kapten muslihat',
#  'i love': 'kiai maja',
#  'banjarnegara': ', para',
#  'eri peri': 'peri kemerdekaan',
#  'sidoarjo)': 'jln raya waru',
#  'dew dew': 'dew v',
#  'gede gede bage': 'gede bage sela',
#  'a damar': 'damar 5',
#  'kricak': 'jl.jambon',
#  'jajar tunggal jajar tung': 'jajar tung sela ii',
#  '70': 'jl.gereja moria liliba',
#  'purwodadi purwo': 'purwodadi utara',
#  'mare mare': 'marelan raya',
#  'jl. raden intan.': 'jl. raden intan',
#  'tegal)': 'jl. perintis kemerdekaan',
#  'duta indahjati mak': 'duta indah raya',
#  'jalan utan jayakampung': 'jalan utan jaya',
#  'jl. mm': 'jl. sulawesi',
#  'mad ahmad': 'ahmad yani',
#  'raya pucang-kayen': 'raya gabus-pati',
#  'jl. raya kesambentimur': 'jl. raya kesamben',
#  'tirto tirto indah': 'tirto indah 8',
#  'tanah sereal kel.': 'tanah ser 18',
#  'bu de': 'bunga sriga',
#  'mitra sunter mitra': 'mitra sun bule',
#  'putat jaya putat jaya barat': 'putat jaya barat vi b',
#  'jatiranggon': 'jl. setiawarga 2',
#  'sd negeri': 'sd inp',
#  'mitr mitra raya batam': 'mitra raya batam center',
#  'muara muara bungo - jambi sek tebo ten sum sari': 'muara bungo - jambi sek tebo ten sum sari 002',
#  'banyu urip banyu urip kidul ii': 'banyu urip kidul ii molin 3',
#  'jl. pramuka jl. lingkar': 'jl. lingkar danau buatan',
#  'k k. h. mas': 'k. h. mas mans',
#  'gar cutt': 'pagar alam',
#  'l jl sei': 'jl sei asahan',
#  'singo singo timur': 'singo timur ii',
#  'tambang': 'jalan suka nusa',
#  'r parmiasih rawa': 'rawa kepa 8',
#  'a meu raya': 'raya kota batu',
#  'baloi indah': 'baloi pers',
#  'jl bekasi timur rayahalte': 'jl bekasi timur raya',
#  'made kel.': 'made lak',
#  'kapuk kapuk pasar': 'kapuk pasar alam',
#  'jl cempakabr.': 'jl cempaka',
#  'jetisharjo jetish jt': 'jetisharjo jt ii',
#  'jalan smp 122.': 'jalan smp 122',
#  'jl. jayalaras': 'jl. gkpn',
#  'muti residence': 'muti 15',
#  'jln. kampung pulo.': 'jln. kampung pulo',
#  'rajawali outd': 'rajawali sela',
#  'benda baru benda tim': 'benda tim 8 b',
#  'jl.jalak harupatrt': 'jl.jalak harupat',
#  'karah karah v': 'karah v a',
#  'baji mappakasunggu baji': 'baji ampea lr',
#  'l no. 15 jl.': 'jl. wahid hasyim 2',
#  'rangkah rang': 'rangkah i',
#  'kalki': 'jl.kebon kawung',
#  'jl perintis kemerdekaan 3btn': 'jl perintis kemerdekaan 3',
#  'pluit pluit utara': 'pluit utara raya',
#  'sat sat': 'sat jaya',
#  'a 9 man': 'man dua raya',
#  'jl. lempuyang i.perumahan': 'jl. lempuyang i',
#  'cipag per cipag': 'cipag per 2',
#  'r lor': 'lor rah',
#  'jagir jagir sidoresmo': 'jagir sidoresmo xi',
#  'jl.indra prastakalisapu': 'jl.indra prasta',
#  'j no.2 jl. bukit': 'jl. bukit cinere raya',
#  'balun balun': 'balun sudag',
#  'no.45a)': 'jl. bangka raya',
#  'parak gadang': 'parak gad',
#  'bukit pakar hotel bukit': 'bukit pakar timur atas',
#  'soe soek': 'soek hatta',
#  'jalan pancoran barat vii.': 'jalan pancoran barat vii',
#  'm trans': 'sum sari',
#  'jl. asemkajl': 'jl. asemka',
#  'singkil sing': 'singkil rimo',
#  'pisangan baru pisangan': 'pisangan baru ten',
#  'maleber male': 'maleber utara',
#  'mare mare 1 pasar 4 bar gg.': 'mare 1 pasar 4 bar gg. fam',
#  'cilangkap)': 'jl raya cilangkap',
#  'jl. andi djemma(landak': 'jl. andi djemma',
#  'mangga besar mangga': 'mangga besar raya',
#  'pakis ii- 369': 'pakis tirtosari x',
#  'jalan sukamulya raya.': 'jalan sukamulya raya',
#  'citra sari rasa': 'citra raya boule',
#  'griya permata cisoka': 'griya perm cis',
#  'setia budi setia': 'setia budi 2',
#  'jln.abdullah daeng siruabatuakec.': 'jln.abdullah daeng sirua',
#  'fajar abadi': 'fajar baru',
#  'cipe 1': 'cipe i',
#  'seririt seri': 'seririt- singa',
#  'jagasatrudesa:hegarmuktikabupaten:bekasi': 'jln jagasatru',
#  'askrindo)': 'jl.17 agustus',
#  'coklat)': 'jl.jendral sudirman',
#  'rasamala llljl.rasamala': 'jl.rasamala iii',
#  'a lsb asb': 'raya suka sela',
#  'sidodadi sidodadi kul gg.': 'sidodadi kul gg. i',
#  'cilendek barat cile': 'cilendek indah iii',
#  'rawa terate': 'rawa ter',
#  'jl. pluit karang ayu barat.': 'jl. pluit karang ayu barat',
#  'a hidayat griya': 'griya pipit vi',
#  'jl.setu baru.': 'jl.setu baru',
#  'dan tata rias': 'medan bat kuis',
#  'johar baru johar ba v': 'johar ba v g rr',
#  'pt angsa': 'cipto mangulir',
#  'jln. teknik elektro.': 'jln. teknik elektro',
#  'dukuh kupang disa wall': 'dukuh kup timur xv',
#  'tanjung duren tanj': 'tanjung duren barat',
#  'a lantai': 'jln.bangka raya',
#  'muchtarcimahpar': 'jln guru muchtar',
#  'cibiru wetan cib': 'cibiru indah 7',
#  'putat jaya putat jaya timur': 'putat jaya timur iii b',
#  'kali anyar kali anyar x': 'kali anyar x, gg. 5',
#  'mel prem mel': 'mel raya timur',
#  'a harjam indah': 'harjam indah est',
#  'kart vocational': 'kart 3',
#  'rawa buntu rawa buntu ruko griya': 'rawa buntu ruko griya loka 1.1',
#  'ceper': 'jl.garuda',
#  'telepon': 'jl bethesda',
#  'jl. jamin ginting kantor': 'jl. kapten pala bangun',
#  'u u': 'u raya',
#  '1 10': '10 a',
#  'jl merdeka.': 'jl merdeka',
#  'jl. taman surya 5pasar': 'jl. taman surya 5',
#  'umalas uma': 'umalas klec',
#  'dukuh kupang dukuh kupa': 'dukuh kupa gg. lebar',
#  'urip urip': 'urip sumoh',
#  'kedoya utara': 'kedoya raya',
#  'puri dewata': 'puri 1',
#  'jeron jeron': 'jeron raya',
#  'e.06.b': 'jl.pluit karang ayu barat',
#  'ma reum taman': 'taman ken jago',
#  'keluar': 'jl raden intan',
#  'geger kal': 'gegerk ten',
#  'no.6ket': 'jalan ketabang kali',
#  'palagan palagan tent': 'palagan tent pela',
#  'wij grand': 'wij ii',
#  'jalan hadiah utama.': 'jalan hadiah utama',
#  'jln. pangeran ratu.': 'jln. pangeran ratu',
#  'jl mojoagung.emerald': 'jl mojoagung',
#  'krukut krukut': 'krukut pasar',
#  'jl. arteri jl. mangga': 'jl. mangga dua raya',
#  'b bukit kena': 'bukit kena 1',
#  'rw.003jatiranggon': 'jl.setiawarga 2',
#  'jl. timah 1.': 'jl. timah 1',
#  'jl cijamberuko': 'jl cijambe',
#  'bangka rayaunit': 'jl.bangka raya',
#  'n roll': 'danau jonge',
#  "kh. a syafi'ie": 'kh. abdullah syaf',
#  'ampel ampel gubah': 'ampel gubah lor',
#  '75391': 'jl.moeis hasan',
#  'bambu bambu mas utara': 'bambu mas utara i',
#  'kart dewata': 'kart plaza',
#  'dukuh dukuh v': 'dukuh v dalam',
#  'd tuti': 'gadog raya',
#  'jl. mayjen sungkono.': 'jl. mayjen sungkono',
#  'tebet timur tebet': 'tebet utara dalam',
#  'pagesangan pagesangan asri': 'pagesangan asri ix',
#  'karema': 'jln urip sumoharjo',
#  'lagoa lagoa teru gg.': 'lagoa teru gg. vc',
#  'kali kedinding kali lor ind': 'kali lor ind gg. mawar',
#  'jl. angkatan 66.': 'jl. angkatan 66',
#  'jl. mujair rayabambu': 'jl. mujair raya',
#  'dan beauty danau': 'danau sentani i',
#  'pab sedati': 'pab asri',
#  'jalan vila nusa indah 5cluster': 'jalan vila nusa indah 5',
#  'kiara park': 'kiara cond',
#  'warung buncit gedung': 'jl.warung buncit raya',
#  'ps 3': 'ps barat',
#  'maha perum tanah bang': 'perumahan tanah bang per',
#  'alau alau plaza &': 'alau plaza & townh',
#  'kulon': ', ked mul 2 cak gg. 1',
#  'jl. raya cisaukdesa': 'jl. raya cisauk',
#  'halim perdana kusumah': 'halim perd kus',
#  'jl. timor.': 'jl. timor',
#  'ploso kel. ploso timur': 'ploso timur iii a',
#  'i conb indon surya manado.': 'citra land city of blessings',
#  'citra mas citra': 'citra mas indah',
#  'talun talun': 'talun kidul',
#  'pes darussalam': 'pes daruss',
#  'marg tour': 'marg raya',
#  '. jl. sasak': 'jl. sasak raya',
#  'pasar lama pasar': 'pasar lama laut',
#  'jl. kp. bakom': 'jl. raya narogong',
#  'timur61256': 'jln raya waru',
#  'j 6 jl.': 'jl. desa cipadung',
#  'tegal tegal': 'tegal bina',
#  'n mare': 'marelan raya',
#  'kec.paninggaran': 'jl.raya paninggaran',
#  'jln. cendrawasih raya.': 'jln. cendrawasih raya',
#  'kramat kramat senti gg.': 'kramat senti gg. v',
#  '. samping pom bensin': 'jl. brigjen saptadji hadiprawira',
#  'jl. ring road utaracondongcatursleman': 'jl. ring road utara',
#  'cipinang melayu': 'cipinang ten',
#  'a bhayu k.': 'semampir barat ii',
#  'made kel. made': 'made taman selatan',
#  'krekot spesi': 'krekot bun',
#  'i d.i.': 'd.i. panja',
#  'artha gadi lan': 'artha gad sela',
#  'jl.jendral ahmad yanipadasuka.': 'jl.jendral ahmad yani',
#  'jl. balai rakyatnote:': 'jl. balai rakyat',
#  'ina ina': 'ina boi',
#  'lagoa lagoa trs gg.': 'lagoa trs, gg. iv',
#  'muktiharjo kidul': 'muktiharjo raya',
#  'dupak dupak ban': 'dupak ban ten',
#  'kali kedinding kali lor': 'kali lor timur iv',
#  'cemp putih tengah 33': 'cemp putih ten 33b',
#  'a hong': 'kebay lama',
#  'jln bojong indah raya.': 'jln bojong indah raya',
#  'pisa timur pisa': 'pisa lama sela',
#  'war makan selera': 'war jati barat',
#  'bungo pasang': 'bungo pas',
#  'jl guru muchtar.': 'jl guru muchtar',
#  'mr studio': 'mr kusbi',
#  'l unit 19 ab. jl.': 'jl. pluit karang ayu barat',
#  'lebak van java': 'lebak jaya utara',
#  'batu sondat': 'batu son',
#  'agung agung utara 8a': 'agung utara 8a  b',
#  "kosambi d'fi laundry": 'kosambi utara raya',
#  'kota bambu utara kota bambu': 'kota bambu uta gg. f',
#  'u i': 'budi utomo',
#  'e peta': 'peta barat',
#  'kuin cerucuk': 'kuin selatan',
#  'tangerang': 'jl.masjid at-tauhid',
#  'jl. lingkar timur.': 'jl. lingkar timur',
#  'jl.adi sucipto.': 'jl.adi sucipto',
#  'desa rengasbandung': 'desa sarwodadi',
#  'hills)': 'jl. swadaya 3',
#  'jl. lingkar danau buatan.': 'jl. lingkar danau buatan',
#  '. kpp 100': 'jl. mayjend sungkono',
#  'jl tanah abang ii.': 'jl tanah abang ii',
#  'jaksa ag jaksa': 'jaksa agung supr',
#  'a 05 unit ap green': 'jalan pluit karang ayu barat',
#  'jl seth adji(sebelah': 'jl seth adji',
#  'mayang may': 'mayang karta',
#  'i ga.': 'wisma uday',
#  'jln. ambon.': 'jln. ambon',
#  'g spo': 'gajah mada',
#  'manis jl.manis': 'jl.manis ii',
#  'school)': 'jl pulo mas jaya',
#  '15': 'jln.tanah pasir',
#  'lidah kulon lidah kul': 'lidah kul g ii',
#  'pluit ger pantekosta di': 'pluit kar per 12',
#  'melawi': 'jl lintas melawi',
#  'e mobil': 'kedung 6',
#  'jl. lingkar selatan.': 'jl. lingkar selatan',
#  'jl. puri gadingblok': 'jl. puri gading',
#  'getas pejaten getas peja': 'getas peja gang harj',
#  'puri sakti': 'puri anjas',
#  'srg03)': 'jl.ngaliyan permai ii',
#  'bulak banteng bulak bant': 'bulak bant lor. i',
#  'man man town': 'man town squ',
#  'batu jl.batu': 'jl.batu raya',
#  'jl. hartono raya.': 'jl. hartono raya',
#  'jl ganet.': 'jl ganet',
#  'm cemp mas': 'cemp mas barat',
#  'id sido': 'sido indah',
#  'jl. duren baru.': 'jl. duren baru',
#  'n 12': 'gun lawu',
#  'utan panjang kel.': 'utan panjang iii',
#  'senen pusat': 'senen jaya',
#  'cempedak)': 'jl. di. panjaitan',
#  'melong mel': 'melong nyon',
#  'griya tim estate': 'griya tim est',
#  'e ki': 'dewi sart',
#  'jalan batu bolong 2.btn': 'jalan batu bolong 2',
#  'jln raya regency ii.kuta': 'jln raya regency ii',
#  'jl.jamin gintingpadang': 'jl.jamin ginting',
#  'dan tata': 'medan-t tin',
#  'jatiranggonkec.jatisampurna.': 'jalan swadaya 3',
#  'mojo mojo gg.': 'mojo, gg. iv',
#  'jln garuda bawah.': 'jln garuda bawah',
#  'lidah wetan lidah': 'lidah hara xvii',
#  'jl. ir. sutami': 'jl. tol lama',
#  'plam hijau plamo': 'plamo per ii',
#  'jl. lingkar timurmandingtrir': 'jl. lingkar timur',
#  'nusantarakawungluwukkec.sukaresmikab.cianjur': 'jl.mariwati',
#  'jagir tre': 'jagir wonok',
#  'jl. kp.': 'jl. padurenan',
#  'haw garden': 'hawai gar',
#  'bintara dirayna': 'bintara raya',
#  'pel pelita': 'pelita ii',
#  'jalan bima sakticilaja-': 'jalan bima sakti',
#  'kart kart': 'kart raya',
#  'jln raden intan.': 'jln raden intan',
#  'jl. s. parmankec.': 'jl. s. parman',
#  'mojo mojo': 'mojo kidul',
#  'sar pasar': 'pasar jambul',
#  'jl kawaluyaanjatisarikec.kiaracondongwarung': 'jl kawaluyaan',
#  'tebet timur kel. tebet': 'tebet utara 1 e',
#  'a jl.kesehatan': 'jl.kesehatan vi',
#  'marunda marunda baru': 'marunda baru iv',
#  'poris gaga poris': 'poris para ekskl',
#  'jl amperakomplek': 'jl ampera',
#  'pancoran kel. panc': 'pancoran barat 7',
#  'mard 22': 'mard raya',
#  'kepa kepa duri': 'kepa duri mas',
#  'ciku 5': 'cikutra timur',
#  'paku jaya paku jaya': 'paku jaya per 4',
#  'gadel gadel sari': 'gadel sari madya',
#  'jati ruko': 'jati raya',
#  'cipinang besar': 'cipinang pulo',
#  'm dan': 'kamal raya',
#  'gading barat gad kir': 'gading kir timur v',
#  'jl jendral sudirmankantor': 'jl jendral sudirman',
#  'gub 2 gub': 'gub jaya ii',
#  'a sen man': 'man besar 3',
#  'citra 7 citra gar': 'citra gar city 7',
#  'p dan': 'pang adi',
#  'kebon melati thamrin': 'kebon kacang raya',
#  'kali baru kalibaru barat ia': 'kalibaru barat ia, gg. sadar',
#  'praya tengah': 'praya timur',
#  'palem ac': 'palem raya',
#  'cemp putih cemp putih': 'cemp putih ten 13',
#  'jln gajah madasei': 'jln gajah mada',
#  'kalijudan kalijudan tar': 'kalijudan tar ii',
#  'rawa buntu rawa': 'rawa buntu sela',
#  'jend jend': 'jenderal sudi',
#  'jl. sultan agung.': 'jl. sultan agung',
#  'j 407 jl': 'jl teknik elektro',
#  'wijaya motor wijaya': 'wijaya kusu iii',
#  'dukuh menanggal': 'dukuh menan',
#  'jln mayawati..pemangkas': 'jln mayawati',
#  'jl. ganet.': 'jl. ganet',
#  'kali anyar kali anyar': 'kali anyar x, g',
#  'j n t': 'jl. jendral sudirman',
#  'jl. inspeksi cidurian': 'jl. soekarno hatta',
#  'd desa': 'desa bring',
#  'keb.melati': 'jl.jati bunder',
#  'jalan martapura lama.km': 'jalan martapura lama',
#  'scientia square': 'jl.scientia boulevard',
#  'kali anyar kali any': 'kali any gg. 3',
#  'duri pulo duri b': 'duri b, gg. iv',
#  'salam salam': 'salam raya',
#  'cendra cendra 25 town': 'cendra 25 town house',
#  'taman legian': 'taman leg',
#  'h yusrizal ghazalis.h.m.h': 'kh ahmad dah',
#  'delta)': 'jl. lingkar barat',
#  'tiban indah kedai': 'tiban indah permai',
#  'e)': 'jalan pancoran barat vii',
#  'di indonesia': 'yudis tag',
#  'pulo satu': 'pulo utara',
#  'no.09': 'jln.pattimura',
#  'jalan sungai raya dalamkomplek': 'jalan sungai raya dalam',
#  'sema sema': 'sema raya',
#  'jajar tunggal jajartunggal': 'jajartunggal sela iii',
#  'raya tb': 'raya jong',
#  'duri selatan blouse': 'duri selatan 5',
#  'muti hati': 'mutiara 3',
#  'jl.soekarno hatta.': 'jl.soekarno hatta',
#  'cikampek-bts. suban pangulah': 'cikampek-bts. subang ka',
#  'pantai cermin': 'pantai cer',
#  'pejaten barat': 'pejaten raya',
#  'tebet timur kedai': 'tebet timur raya',
#  '. grace': 'dr. setiab',
#  'pt kap': 'kapten japa',
#  'ciga mak ciga': 'ciga raya ten',
#  'jl. lampiri rayajalan': 'jl. lampiri raya',
#  'waru waru surya': 'waru surya indah',
#  'jl. ambon.': 'jl. ambon',
#  'jl. indotaisei raya jl. kota': 'jl. kota bukit indah raya',
#  'tebet timur mush baiturrohim': 'tebet timur 4 f',
#  'jl. anggrek[mutiara': 'jl. anggrek',
#  'pacar keling haryanto pacar': 'pacar kel gang v',
#  'jln trans kalimantan.': 'jln trans kalimantan',
#  'jl. jalur sutera barat.': 'jl. jalur sutera barat',
#  'ska ( cik': 'skar n iv',
#  'tirta squ': 'tirta raya',
#  'haka haka': 'haka 10',
#  'jalan mujair rayabambu': 'jalan mujair raya',
#  'bint sektor 5': 'bintaro utama 5',
#  'tambak wedi sayur bu': 'tambak wedi baru vi',
#  'jl. perintis kemerdekaan 3.': 'jl. perintis kemerdekaan 3',
#  'jl.pangeran ratu.15.ulu': 'jl.pangeran ratu',
#  'dukuh kupang pasar': 'dukuh kup barat',
#  'jl. jatijajar 1.': 'jl. jatijajar 1',
#  'pisangan baru pisa': 'pisangan baru ten',
#  'kota bambu selatan kota bambu sela': 'kota bambu sela 2, gg. iii',
#  'pandansari pandansari': 'pandansari raya',
#  'al iskan': 'malik ibra',
#  'bah bah': 'bah i',
#  'jln raya marina citytanjung': 'jln raya marina city',
#  'simo hilir simo hilir': 'simo hilir barat vi',
#  'm muria': 'muria raya',
#  'i bilal': 'bilal ujung',
#  'bibis bibis tama': 'bibis tama v',
#  'johar johar baru utara': 'johar baru utara 3',
#  'saja)': 'jln.lamtoro',
#  'l no. 2': 'jl. tropodo i',
#  'sumbersari sumber gg.': 'sumbersari, gg. 4',
#  'duren tiga duren tiga': 'duren tiga sela vii',
#  'beli beli': 'beli darat',
#  'a bas': 'basuki rah',
#  'kali kali ten': 'kali ten 11',
#  'dupak dupak ban rejo': 'dupak ban rejo iv',
#  'balongsari balongsari tama timur': 'balongsari tama timur iii',
#  'ser ser': 'ser i',
#  'tanjung duren selatan': 'tanjung duren raya',
#  'jl veteran jl terusan': 'jl terusan ibrahim singadilaga',
#  'm biomed': 'taman gard',
#  'a l00': 'raya cira',
#  'taman ratu taman': 'taman ratu raya',
#  'sei arakundo': 'sei arak',
#  'curug curug': 'curug induk',
#  'cipa cipa': 'cipayung raya',
#  'jln gub h bastaribasecamp': 'jln gub h bastari',
#  'melong kel.': 'melong raya',
#  'jalan candi': 'jalan kaliurang',
#  'asri wisata': 'asri kober',
#  'p pura': 'pura demak',
#  'parak karakah': 'parak kara',
#  'jl.raya junwangikriansidoarjo': 'jl.raya junwangi',
#  'gading barat': 'gading kir',
#  '15)': 'jl. canadian broadway',
#  'komplek indovilla': 'komplek indov',
#  'es lilin': 'desa rah',
#  'rorotan kantorpos': 'rorotan raya',
#  'jl. lingkar selatan.kenali': 'jl. lingkar selatan',
#  'siwalankerto siwalan utara': 'siwalankerto utara ii',
#  '2a)': 'jalan hadiah utama',
#  'jl. aria putra.': 'jl. aria putra',
#  'pakis pakis sid': 'pakis sid iv',
#  'jalan panglima denai': 'jalan jermal vii',
#  'pluit pluit kar asri': 'pluit kar asri ii',
#  'a kas': 'kebay lama',
#  'a no.5 jalan': 'jalan utan jaya',
#  'kali kedinding kali baru': 'kali baru 1 a',
#  'jln benteng betawi.': 'jln benteng betawi',
#  'h maul kh': 'kh saman hudi',
#  'bulak banteng bulak bant baru': 'bulak bant baru, gg. ii',
#  'jl pasar kembangsosromendurangedongtengen': 'jl pasar kembang',
#  'jl. garuda kencanakec.serpongkota': 'jl. garuda kencana',
#  'lin timur lin': 'lin timur keri',
#  'dago kedai laksa': 'dago elos iv',
#  'peri perintis': 'perintis kemerdekaan',
#  'pondok bahar pon': 'pondok bahar utama',
#  'jln. kapten abdullah.': 'jln. kapten abdullah',
#  'bsd city bsd': 'bsd grand boule',
#  'pluit tower akasia unit': 'jln.pluit karang ayu barat',
#  'jl.cendrawasih rayasawah': 'jl.cendrawasih raya',
#  '8036': 'jalan puri gading',
#  'ampel ampel kesu': 'ampel kesu pasar',
#  'karah karah indah': 'karah indah i',
#  'jl. legenda wisata boulevardcluster': 'jl. legenda wisata boulevard',
#  'jl. cendana rawakalongblok': 'jl. cendana rawakalong',
#  'jl lintas sumatra': 'jl nurul persada',
#  'griya inti': 'jl.griya agung',
#  'ploso ploso timur iii': 'ploso timur iii a',
#  'pluit tower h10ae jl.pluit': 'jl.pluit karang ayu barat',
#  'jl. aria putraparadise': 'jl. aria putra',
#  'jl.rajawali selatan rayahalte': 'jl.rajawali selatan raya',
#  'karet kuningan karet pedur mas 2': 'karet pedur mas 2, gg. belim',
#  'pluit mall lt.': 'pluit sela raya',
#  'bojong rawalumbu dapur': 'bojong utama raya',
#  'made made karyo': 'made karyo 2',
#  'jl. setiabudhi dalamwarkop': 'jl. setiabudhi dalam',
#  'a cha raya': 'raya 18 cimucang',
#  'jl permata indah.': 'jl permata indah',
#  'benda benda barat xii': 'benda barat xii b',
#  'karah karah agung': 'karah agung xii',
#  'piai tangah': 'piai atas',
#  'kebon pedes kebon': 'kebon pedes 1',
#  'jl. niaga raya': 'jl. jababeka ii',
#  'ancol ancol': 'ancol ten',
#  'cendana cend': 'cendana i',
#  '. jl.ketut adi': 'jl.ketut adi sanyoto',
#  's stas': 'stas dela',
#  'ma neg': 'imam bon',
#  'man taman mini': 'taman mini i',
#  '(puar)': ', kamp baru',
#  'jat jati': 'jati raya',
#  'nata endah nata': 'nata asih 1',
#  'ment ment kenj': 'ment kenj barat',
#  'jl. gedong panjangkumala': 'jl. gedong panjang',
#  'raya cell raya': 'raya kanal nguj',
#  'pinangsia wira': 'pinangsia timur',
#  'al khoi': 'kali barat',
#  'pelepah elok pele': 'pelepah elok 1',
#  'bu siti pati bule': 'bule timur kel gading',
#  '.pekunden': 'jl pandanaran',
#  'jl. h.': 'jl. pln',
#  'cijarua': 'jl.margacinta',
#  'puri gading i': 'puri gad raya',
#  'jambangan kel. jambangan': 'jambangan indah i',
#  'jl. cumi raya': 'jl. muara baru',
#  'pulo mas jl.pulo': 'jl.pulo mas jaya',
#  'al amaliyah': 'palimanan i',
#  'jl.garuda kencanagolden': 'jl.garuda kencana',
#  'd cre jend': 'jend gatot subr',
#  'ma dar': 'man sakti',
#  'gal gala': 'gala raya',
#  'utan kayu utara': 'utan kayu raya',
#  'jaya sdm': 'jaya i',
#  'setu setu indah': 'setu indah iv',
#  'rasa bakso': 'rasa raya',
#  'no.4': 'jl. jendral sudirman',
#  'pondok karya pondok': 'pondok bet raya',
#  '. jl. oro-oro': 'jl. oro-oro ombo',
#  'karet karet jaya': 'karet jaya raya',
#  'lay sari': 'lay ii',
#  'pinus pinus': 'pinus raya',
#  'karya tsaqila': 'karya bakti',
#  'gemah gemah barat': 'gemah barat i',
#  'taman sari kel.': 'taman sari 8',
#  'wono wono': 'wono sela',
#  'jl. masjid.ciater': 'jl. masjid',
#  'pondo pondok jaya': 'pondok jaya 6',
#  'jalan manggis.': 'jalan manggis',
#  'jl ciputat raya.': 'jl ciputat raya',
#  'jl. kacapiring iii.': 'jl. kacapiring iii',
#  'bukit mulia bukit': 'bukit sarua raya',
#  'ro rang prof haji m': 'profesor haji m yamin sh',
#  'suka maju suka': 'suka karya iii',
#  'duatangerang-banten': 'jl.boulevard raya gading serpong',
#  'rw4': 'jl.kampung rawa ii',
#  'k pot': 'kh must',
#  'kebon sirih kebon sirih barat i': 'kebon sirih barat i, gg. 10',
#  'peterongan': 'jl mt. haryono',
#  'angke laun': 'angke jaya',
#  'sentani': 'jln rajawali selatan raya',
#  'perum kadum asri perum': 'perum citra permata sakinah',
#  'apus': 'jl. aria putra',
#  'toko pertokoan glo': 'pertokoan glo blus',
#  'ceger ceger': 'ceger raya',
#  "n d'kos": 'asahan 1',
#  'sutorejo sutorejo sela': 'sutorejo sela vii',
#  '16': 'jl kenanga 4',
#  'r brig kata': 'brig kata dalam',
#  'peru antang': 'peru raya',
#  'ciater cia per': 'ciater per raya',
#  'parit tokaya': 'parit dem',
#  'a end': 'anye 2',
#  'gemah gemah kenc': 'gemah kenc v',
#  'i karantina': 'karantina ii',
#  'g marg': 'marg raya',
#  'rungkut tengah rungkut mapan': 'rungkut mapan barat iv',
#  'ma negeri': 'man 2',
#  'batu ampar asia': 'batu ampar 1',
#  'raya pohw': 'raya kedung',
#  'pt cipta': 'cipta karya',
#  'mauk': 'jln raya mauk',
#  'senen senen': 'senen raya',
#  'h ulis': 'cihe kaum',
#  'bukit duri sinar': 'bukit duri sela',
#  'lor mari': 'lorong pergu',
#  'kaliga purwakarta': 'kaligandu 2',
#  'surya cipta': 'surya madya',
#  'jln suka damaiserua': 'jln suka damai',
#  'dupak dupak pasar': 'dupak pasar baru',
#  'pademangan timur pademangan': 'pademangan, gg. xxx',
#  'jl gudang minyak..': 'jl gudang minyak',
#  'n 21 ponti': 'tanj raya 2',
#  '36a': 'jl.raya wonorejo',
#  'bulak bulak cum': 'bulak cum barat',
#  'ak bihun': 'baka batu',
#  'jl. paus jl.': 'jl. ambu ambu',
#  'pondok kopi pon': 'pondok kopi iv',
#  'taman sari taman': 'taman sari vi',
#  'serp jaya': 'serpong raya',
#  'b bunga rampe': 'bunga rampe raya',
#  'am keb taman': 'taman keba indah',
#  'mojo mojo klan wetan': 'mojo klan wetan iv',
#  'balekambang': 'jl kayu manis',
#  'suka bumi': 'suka sela',
#  'a door': 'raden fattah',
#  'p a': 'peri kem',
#  'kebon kacang bc': 'kebon kac 9',
#  'tegal panggung': 'tegal pang',
#  'kesiman': 'jl pralina',
#  'raya deandles': 'raya sugio',
#  'pakal pakal': 'pakal mad',
#  'jl.arcamanik endah.ruko': 'jl.arcamanik endah',
#  'bat batununggal indah': 'batununggal indah raya',
#  'citra graha sejahtera citra': 'citra graha sejah resid',
#  'sei batang sei': 'sei bat hari',
#  'jl. jl. letkol pol. h.m. asnawi': 'jl. letkol pol. h.m. asnawi arbain',
#  'pasar minggu pasar': 'pasar minggu raya',
#  'panjang jiwo kel. panj': 'panjang jiwo per ii',
#  'keputih toko raisa': 'keputih gang 1',
#  'jln.sultan hasanuddintipulu': 'jln.sultan hasanuddin',
#  'paluh kurau': 'paluh hiu',
#  's bak sriwi komp': 'sriwi komp suri graha',
#  'wonokromo tresno': 'wonokromo tang',
#  'kem prat kemang': 'kemang prat raya',
#  'rumah labu kun': 'perumahan btn green',
#  'muti asri muti': 'mutiara elok 4',
#  'rawa rawa sela gg.': 'rawa sela gg. angs',
#  'n 1 pan': 'lin suma kota',
#  'pademangan timur pademangan ii': 'pademangan ii, gg. 20',
#  'tebet barat tebet mas': 'tebet mas indah iv',
#  'raya mak raya': 'raya plp curug',
#  'karasak kara ten': 'karasak ten i',
#  'puri hrpn': 'puri hara',
#  'duri kosambi duri': 'duri cen raya',
#  'tebet barat tebet barat raya 1': 'tebet barat raya 1 rusun berl',
#  'duren sawit duren sawit': 'duren sawit timur v',
#  'sei batu': 'sei silau',
#  'mangga dua.. jln.mangga': 'jln.mangga dua raya',
#  'jl balai rakyatpesona': 'jl balai rakyat',
#  'jln.pulau batamno.1': 'jln.pulau batam',
#  'wonorejo wonorejo': 'wonorejo i',
#  'jl. projakal.': 'jl. projakal',
#  'jln. setujln.rawa': 'jln.rawa lindung',
#  'jalan mangga dua dalam.': 'jalan mangga dua dalam',
#  'pengadegan kel.': 'pengadegan utara',
#  'bungurasih toko': 'bungurasih timur',
#  'h ibrahim tgh': 'tgh abdul hap',
#  'l "': 'jl.nyiur melambai',
#  'peru peru': 'peru wakk',
#  'rm nona manis dha': 'dharma hus indah ii',
#  'duren sawit duren': 'duren sawit baru',
#  'an nad bimbi haji': 'tarian raya barat timur',
#  'peri peri': 'peri kemerd',
#  'dan lt.11 medan': 'medan merd sela',
#  'gadel gadel sari madya': 'gadel sari madya iii',
#  'pram pram': 'pram 6',
#  'kalibata city': 'kalibata raya',
#  'jln ahmad yani.': 'jln ahmad yani',
#  'garu mas': 'garu vi',
#  'muti carita': 'muti car',
#  'celullar': 'jl karanggetas',
#  'jalan gunung gunturperum': 'jalan gunung guntur',
#  'ampera garden': 'jl.ampera raya',
#  'karet kel. karet': 'karet karya 5',
#  'jl. tentara': 'jl. cilendek',
#  'jalan subak sok wayahpejeng': 'jalan subak sok wayah',
#  'jl. raya tonjong.': 'jl. raya tonjong',
#  'jl. pasar vii': 'jl. jamin ginting',
#  'pekanbatu': 'jln rajawali sakti',
#  'kab.pacitan': 'jl.brawijaya',
#  '123': 'jl ngagel',
#  'halim 2': 'halim perdana',
#  'jl. tusam raya.': 'jl. tusam raya',
#  'jl. babakan madangkec.': 'jl. babakan madang',
#  'jl. gatot subroto.': 'jl. gatot subroto',
#  'ria muria': 'muria raya',
#  'h syam bahri': 'hang tuah iv',
#  'karanggan karanggan': 'karanggan muda',
#  'benda baru taman': 'benda timur 9',
#  'kemu kemu': 'kemu raya',
#  's fash': 'kesa wetan',
#  'royal meditera royal med': 'royal med gar reside',
#  'puri puri': 'puri indah',
#  'agung agung niaga': 'agung niaga iii',
#  'a 46': 'jl.loncat indah',
#  'bulak bulak kal': 'bulak kal ii',
#  '. jl. curug': 'jl. curug agung',
#  'dukuh menanggal grace': 'dukuh menan i',
#  'i rengasde': 'depati rahat',
#  'nan balimo': 'letnan dar',
#  'sa adah': 'kalisari iii',
#  'alam sutera w-8r': 'alam sut boulevard',
#  'jalan taruna.': 'jalan taruna',
#  'limau manis limau manis pasar 13': 'limau manis pasar 13 dusun 6',
#  'at taqwa batas': 'batas batang tuan',
#  'kali rungkut kaliw': 'kaliw gg. mas',
#  'gayung gayungsari barat': 'gayungsari barat x',
#  'ana ps laksa muda': 'laksamana muda yos suda',
#  'kamal muara kamal': 'kamal muara ii',
#  'sidotopo sidotopo jaya': 'sidotopo jaya lebar',
#  'a m p': 'medan teng vii',
#  'puri kenc karah': 'puri kenc karal',
#  'r raya sed': 'raya sed agung',
#  'dukuh kupang dukuh kup barat i': 'dukuh kup barat i, gg. iii',
#  'a gedung': 'jalan.kyai tapa',
#  'desa glong': 'desa kar',
#  'k aka an': 'angke jaya 13',
#  'mitra karawangjl.mitra utara': 'jl.mitra utara ii',
#  'no.73': 'jl.raden intan',
#  'pluit pluit karang': 'pluit karang sela',
#  'jl raya trosobosabowidoro': 'jl raya trosobo',
#  'a yani mega a': 'a yani sen bis',
#  'subroto.': 'jl gatot subroto',
#  'pluit trans': 'pluit kenc',
#  'pantai indah kapuk pan': 'pantai indah utara 2',
#  'taman indah taman': 'taman tirta i',
#  'ayu medayu utara xiv': 'medayu utara xiv a',
#  'setia budi setia budi v': 'setia budi v, gg. iii',
#  'pluit kel. pluit kar': 'pluit kar elok 16',
#  'pondok bambu pon': 'pondok bambu atas',
#  'dhu': 'jl. raya tengah',
#  'jl. jendral sudirman.': 'jl. jendral sudirman',
#  'jl budi luhurdekat': 'jl budi luhur',
#  'balun balun srika gg.': 'balun srika gg. 7',
#  'a cecep': 'raya cinu',
#  'puri indah puri': 'puri lingkar dalam',
#  'pacar kembang pacar kemb': 'pacar kemb vc 1',
#  'raya puspita. cv': 'raya gunung putri',
#  'abd muthalib': 'abdul muth',
#  'cempaka putih timur cempaka': 'cempaka jaya, gg. i',
#  'rambipuji': 'jl.dharmawangsa',
#  'kebon kacang 30': 'kebon kacang 31',
#  'simola kip-': 'simolawang buntu',
#  'jembatan besi kel.': 'jembatan besi raya',
#  'baruk baruk barat': 'baruk barat iii',
#  'jl.sultan iskandar muda.': 'jl.sultan iskandar muda',
#  'wis wis': 'wis utama',
#  'pluit pluit karang elok': 'pluit karang elok i',
#  'babar babar': 'babar yogyak',
#  'kart kart puspa': 'kart puspa raya',
#  'kali satu 1': 'kali pepe baru',
#  'kedinding kedin ten jaya': 'kedinding ten jaya iv',
#  'jl benteng betawiporis': 'jl benteng betawi',
#  'joglo 1': 'joglo raya',
#  'wisata.lambangsari': 'jln sunset avenue',
#  'k keba': 'kebalen wetan',
#  'b beo indah': 'beo indah ii',
#  'as sunah': 'paseh teru',
#  'desa karangjati': 'desa sirau',
#  'karet karet gusu': 'karet gusu iii',
#  'r c siba': 'ksr. dadi kusma',
#  'pegangsaan dua pegangsaan indah': 'pegangsaan indah barat iv',
#  'jl wisma tajur.': 'jl wisma tajur',
#  'par ix': 'par 9',
#  'pulo mas -': 'jl.pulo mas jaya',
#  'jalan nyiur gadingbtn': 'jalan nyiur gading',
#  'jl. panglima cama.': 'jl. panglima cama',
#  'metro permata metro': 'metro perm ii',
#  'glondongsendangadi': 'jl magelang',
#  'citra raya pes': 'citra raya boule',
#  'jl. candi': 'jl. kaliurang',
#  'agung agung': 'agung uta',
#  'jalan bsd raya utamatangerang': 'jalan bsd raya utama',
#  'jl.boulevard grand depok city(samping': 'jl.boulevard grand depok city',
#  'bsd cbd parking': 'bsd grand boule',
#  'jln. trans sulawesi.': 'jln. trans sulawesi',
#  'jagir jagir sidom v': 'jagir sidom v a',
#  'johor johor indah': 'johor indah per',
#  ...}
