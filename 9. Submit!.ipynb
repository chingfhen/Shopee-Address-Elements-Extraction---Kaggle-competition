# %% [markdown]
# # ABOUT:
# - convert to required format and submit

# %% [markdown]
# ## load predictions
# - these answer spans were generated from two nlp tasks
#     1. text classification
#         - we classify if POI and street exists in the address
#             1. if they don't we can just return empty string ""
#             2. if they exists the QA model will find the span
#     2. Question answering task
#         - we asked the QA model these questions
#             1. what is the POI?
#             2. what is the street name?

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\tanch\Documents\Coding Competitions\Shopee\Shopee Address Elements Extraction (local)\predictions\QA predictions 1.csv",index_col = "id")
df = df.iloc[:,1:]
df.POI_span = df.POI_span.fillna("")
df.street_span = df.street_span.fillna("")
df
# Out:
#                                              raw_address  \
# id
# 0                  s. par 53 sidanegara 4 cilacap tengah
# 1                  angg per, baloi indah kel. lubuk baja
# 2                                  asma laun, mand imog,
# 3          ud agung rej, raya nga sri wedari karanganyar
# 4                             cut mutia, 35 baiturrahman
# ...                                                  ...
# 49995                    toko mbak farid semboro semboro
# 49996     vie - tk. ridho kids, vete 3 cari, 16720 ciawi
# 49997                mart dan roti bakar malabar, nasio,
# 49998  graha indah pamulang jl. mujair raya bambu apu...
# 49999                                               adi,
#
#                           POI_span      street_span
# id
# 0                                            s. par
# 1                                          angg per
# 2                        asma laun        mand imog
# 3                     ud agung rej     raya nga sri
# 4                                         cut mutia
# ...                            ...              ...
# 49995              toko mbak farid
# 49996         vie - tk. ridho kids      vete 3 cari
# 49997  mart dan roti bakar malabar            nasio
# 49998                  graha indah  jl. mujair raya
# 49999                          adi              adi
#
# [50000 rows x 3 columns]

# %% [markdown]
# ## load mappings
# - these mappings are one to one
# - they were created from training set
# - if they are seen again in test set we replace the abbreviated answeer with the correct answer

# %%
import pickle
with open(r"C:\Users\tanch\Documents\Coding Competitions\Shopee\Shopee Address Elements Extraction (local)\datasets\Abbr_to_Norm_mappings.pickle", "rb") as f:
    mappings = pickle.load(f)

# %% [markdown]
# - mappings = {'kah nasu': 'kaharu nasu',
#  'ahmad dah iv': 'ahmad dahlan iv',
#  'taman mer': 'taman meruya',
#  'pahl': 'pahlawan',
#  'yos suda': 'yos sudarso'....}

# %%
def adjust_span(span):
    if span=="" or span not in mappings:
        return span
    return mappings[span]

# %% [markdown]
# ## map to new answer spans
# - using the mappings we replace the abbreviated answeer with the correct answer

# %%
df['adjusted_POI_span'] = df.POI_span.apply(lambda span: adjust_span(span))
df['adjusted_street_span'] = df.street_span.apply(lambda span: adjust_span(span))

# %%
df[df.POI_span!=df.adjusted_POI_span]
# Out:
#                                              raw_address            POI_span  \
# id
# 3          ud agung rej, raya nga sri wedari karanganyar        ud agung rej
# 36     m. t. hary, no 11 bank neg indonesia kali rejo...  bank neg indonesia
# 145                                           agen payt,           agen payt
# 168    bank rak indonesia, raya pengas, pengasinan sa...  bank rak indonesia
# 215                                toko gemi, banyuputih           toko gemi
# ...                                                  ...                 ...
# 49454                     toko kelon, raya mauk, kosambi          toko kelon
# 49569                bakso pan, r. a. kart, tunggalpager           bakso pan
# 49581  hayam wuruk c 99 hara jaya toko, rw 5 maphar t...      hara jaya toko
# 49878                                   war cinta, giri,           war cinta
# 49979                toko mona kayu jati tembilahan hulu           toko mona
#
#         street_span      adjusted_POI_span adjusted_street_span
# id
# 3      raya nga sri        ud agung rejeki         raya nga sri
# 36       m. t. hary  bank negara indonesia           m. t. hary
# 145                           agen paytren
# 168     raya pengas  bank rakyat indonesia          raya pengas
# 215                          toko gemilang
# ...             ...                    ...                  ...
# 49454     raya mauk         toko kelontong            raya mauk
# 49569    r. a. kart           bakso pandji           r. a. kart
# 49581   hayam wuruk      harapan jaya toko          hayam wuruk
# 49878          giri           warnet cinta                 giri
# 49979     kayu jati          toko monalisa            kayu jati
#
# [515 rows x 5 columns]

# %%
df[df.street_span!=df.adjusted_street_span]
# Out:
#                                              raw_address          POI_span  \
# id
# 1                  angg per, baloi indah kel. lubuk baja
# 163                                        jela sela 15,
# 448                     raya boj ren rawa burung kosambi
# 532       jatibening baru jati ben ii rt 2 3 pondok gede
# 647                    gun singga 17855 cikarang selatan
# ...                                                  ...               ...
# 49545              rm galuh kencana, raya leuwina, tapos  rm galuh kencana
# 49583            padema ii a pademangan timur pademangan
# 49671                     smp harad perum bukit gad cis,         smp harad
# 49759  pradahkali kendal kel. darmo per sela xii no 3...
# 49994                             m. tau kandai dua woja
#
#                street_span adjusted_POI_span     adjusted_street_span
# id
# 1                 angg per                                anggrek per
# 163           jela sela 15                           jelambar sela 15
# 448           raya boj ren                            raya boj renged
# 532            jati ben ii                             jati bening ii
# 647             gun singga                             gun singgalang
# ...                    ...               ...                      ...
# 49545         raya leuwina  rm galuh kencana       raya leuwinanggung
# 49583          padema ii a                            pademangan ii a
# 49671  perum bukit gad cis         smp harad  perumahan bukit gad cis
# 49759   darmo per sela xii                      darmo permai sela xii
# 49994               m. tau                                  m. taufiq
#
# [434 rows x 5 columns]

# %% [markdown]
# - (above) very few rows, about 1000 had their answer spans changed

# %% [markdown]
# ## Generate submissions
# - we submit two copies
#     1. not adjusted
#     2. adjusted using mappings

# %%
adjusted_df = pd.concat([df.adjusted_POI_span+"/"+df.adjusted_street_span],axis=1)
adjusted_df = adjusted_df.rename(columns  ={0:"POI/street"})
adjusted_df
# Out:
#                               POI/street
# id
# 0                                /s. par
# 1                           /anggrek per
# 2                    asma laun/mand imog
# 3           ud agung rejeki/raya nga sri
# 4                             /cut mutia
# ...                                  ...
# 49995                   toko mbak farid/
# 49996   vie - tk. ridho kids/vete 3 cari
# 49997  mart dan roti bakar malabar/nasio
# 49998        graha indah/jl. mujair raya
# 49999                            adi/adi
#
# [50000 rows x 1 columns]

# %%
not_adjusted_df = pd.concat([df.POI_span+"/"+df.street_span],axis=1)
not_adjusted_df = not_adjusted_df.rename(columns  ={0:"POI/street"})
not_adjusted_df
# Out:
#                               POI/street
# id
# 0                                /s. par
# 1                              /angg per
# 2                    asma laun/mand imog
# 3              ud agung rej/raya nga sri
# 4                             /cut mutia
# ...                                  ...
# 49995                   toko mbak farid/
# 49996   vie - tk. ridho kids/vete 3 cari
# 49997  mart dan roti bakar malabar/nasio
# 49998        graha indah/jl. mujair raya
# 49999                            adi/adi
#
# [50000 rows x 1 columns]

# %%
adjusted_df.to_csv(r"C:\Users\tanch\Documents\Coding Competitions\Shopee\Shopee Address Elements Extraction (local)\predictions\adjusted_pred.csv")
not_adjusted_df.to_csv(r"C:\Users\tanch\Documents\Coding Competitions\Shopee\Shopee Address Elements Extraction (local)\predictions\not_adjusted_pred.csv")
